# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#df = pd.read_csv('movies_raw_data.csv', encoding='latin-1')

# %%
conda install tqdm
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
import pandas as pd

df = pd.read_csv('merged_raw_data_clean.csv', encoding='latin-1')

# %%
df
# Out:
#       Rank                               Title  Adj. Lifetime Gross  \
# 0        2  Star Wars: Episode IV - A New Hope         1.668980e+09
# 1        3                  The Sound of Music         1.335086e+09
# 2        4          E.T. the Extra-Terrestrial         1.329175e+09
# 3        5                             Titanic         1.270102e+09
# 4        7                                Jaws         1.200098e+09
# ..     ...                                 ...                  ...
# 903    996   Spy Kids 2: Island of Lost Dreams         1.384389e+08
# 904    997                        Mystic River         1.383987e+08
# 905    998                         Sea of Love         1.382403e+08
# 906    999                            Scrooged         1.382347e+08
# 907  1,000                Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 0       460998500.0       178119500.0  1977   11000000.0
# ...

# %%
df10 = df.loc[(df['Year'] >= 2010)]

# %%
df10
# Out:
#       Rank                                       Title  Adj. Lifetime Gross  \
# 7       11  Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 11      16                           Avengers: Endgame         8.926696e+08
# 20      29                                The Avengers         7.203768e+08
# 21      30                              Jurassic World         7.195185e+08
# 22      31                               Black Panther         7.146714e+08
# ..     ...                                         ...                  ...
# 891    981                           The Peanuts Movie         1.402333e+08
# 895    986                        The Legend of Tarzan         1.394415e+08
# 900    991                     Lee Daniels' The Butler         1.387800e+08
# 901    992                             Horrible Bosses         1.387154e+08
# 907  1,000                        Central Intelligence         1.381157e+08
#
# ...

# %%
top25df = df10.sort_values(by="Adj. Lifetime Gross", ascending=False).head(25)

# %%
top25df
# Out:
#     Rank                                         Title  Adj. Lifetime Gross  \
# 7     11    Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 11    16                             Avengers: Endgame         8.926696e+08
# 20    29                                  The Avengers         7.203768e+08
# 21    30                                Jurassic World         7.195185e+08
# 22    31                                 Black Panther         7.146714e+08
# 24    36                        Avengers: Infinity War         6.785726e+08
# 30    44       Star Wars: Episode VIII - The Last Jedi         6.333604e+08
# 33    49                                 Incredibles 2         6.212235e+08
# 42    62                  Rogue One: A Star Wars Story         5.663378e+08
# 43    63                                 The Lion King         5.652237e+08
# 52    73                         The Dark Knight Rises         5.395414e+08
# ...

# %%
top25df.to_csv (r'ip_raw_data.csv', index = False, header=True)

# %%
df = pd.read_csv('ip_raw_data.csv', encoding='latin-1')

# %%
df
# Out:
#     Rank                                         Title           IP  \
# 0     11    Star Wars: Episode VII - The Force Awakens  Existing IP
# 1     16                             Avengers: Endgame  Existing IP
# 2     29                                  The Avengers  Existing IP
# 3     30                                Jurassic World  Existing IP
# 4     31                                 Black Panther  Existing IP
# 5     36                        Avengers: Infinity War  Existing IP
# 6     44       Star Wars: Episode VIII - The Last Jedi  Existing IP
# 7     49                                 Incredibles 2  Existing IP
# 8     62                  Rogue One: A Star Wars Story  Existing IP
# 9     63                                 The Lion King  Existing IP
# 10    73                         The Dark Knight Rises  Existing IP
# 11    78                          Beauty and the Beast  Existing IP
# 12    79                                  Finding Dory  Existing IP
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Existing IP', 'Original IP'
sizes = [24, 1]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
