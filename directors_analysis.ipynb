# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#df = pd.read_csv('movies_raw_data.csv', encoding='latin-1')

# %%
conda install tqdm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Bryan/opt/anaconda3
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.2                |           py37_0         2.8 MB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda                                         conda-forge --> pkgs/main
#
#
#
# Downloading and Extracting Packages
# conda-4.8.2          | 2.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
import pandas as pd

df = pd.read_csv('merged_raw_data_clean.csv', encoding='latin-1')

# %%
df
# Out:
#       Rank                               Title  Adj. Lifetime Gross  \
# 0        2  Star Wars: Episode IV - A New Hope         1.668980e+09
# 1        3                  The Sound of Music         1.335086e+09
# 2        4          E.T. the Extra-Terrestrial         1.329175e+09
# 3        5                             Titanic         1.270102e+09
# 4        7                                Jaws         1.200098e+09
# ..     ...                                 ...                  ...
# 903    996   Spy Kids 2: Island of Lost Dreams         1.384389e+08
# 904    997                        Mystic River         1.383987e+08
# 905    998                         Sea of Love         1.382403e+08
# 906    999                            Scrooged         1.382347e+08
# 907  1,000                Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 0       460998500.0       178119500.0  1977   11000000.0
# 1       159287540.0       142485200.0  1965    8200000.0
# 2       435110560.0       141854300.0  1982   10500000.0
# 3       659364000.0       135549800.0  1997  200000000.0
# 4       260000000.0       128078800.0  1975    7000000.0
# ..              ...               ...   ...          ...
# 903      85846430.0        14774700.0  2002   38000000.0
# 904      90135190.0        14770400.0  2003   25000000.0
# 905      58571510.0        14753500.0  1989   10017840.0
# 906      60328560.0        14752900.0  1988   13027842.0
# 907     127440870.0        14740200.0  2016   50000000.0
#
#                     Director  \
# 0               George Lucas
# 1                Robert Wise
# 2           Steven Spielberg
# 3              James Cameron
# 4           Steven Spielberg
# ..                       ...
# 903         Robert Rodriguez
# 904           Clint Eastwood
# 905            Harold Becker
# 906           Richard Donner
# 907  Rawson Marshall Thurber
#
#                                                  Actor  \
# 0    Mark Hamill, Harrison Ford, Carrie Fisher, Ale...
# 1    Julie Andrews, Christopher Plummer, Eleanor Pa...
# 2    Henry Thomas, Drew Barrymore, Peter Coyote, De...
# 3    Leonardo DiCaprio, Kate Winslet, Billy Zane, K...
# 4    Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ..                                                 ...
# 903  Alexa PenaVega, Daryl Sabara, Antonio Banderas...
# 904   Sean Penn, Tim Robbins, Kevin Bacon, Emmy Rossum
# 905  Al Pacino, Ellen Barkin, John Goodman, Michael...
# 906  Bill Murray, Karen Allen, John Forsythe, John ...
# 907  Dwayne Johnson, Kevin Hart, Danielle Nicolet, ...
#
#                                           Genre    IMDB ID  Vote Count  \
# 0            Action, Adventure, Fantasy, Sci-Fi  tt0076759       12970
# 1    Biography, Drama, Family, Musical, Romance  tt0059742        1889
# 2                                Family, Sci-Fi  tt0083866        7280
# 3                                Drama, Romance  tt0120338       16022
# 4                    Adventure, Drama, Thriller  tt0073195        5808
# ..                                          ...        ...         ...
# 903   Action, Adventure, Comedy, Family, Sci-Fi  tt0287717        1297
# 904             Crime, Drama, Mystery, Thriller  tt0327056        3617
# 905    Crime, Drama, Mystery, Romance, Thriller  tt0098273         292
# 906             Comedy, Drama, Fantasy, Romance  tt0096061         800
# 907                       Action, Comedy, Crime  tt1489889        3561
#
#      Vote Average  Popularity
# 0             8.2      41.110
# 1             7.7      14.111
# 2             7.5      17.959
# 3             7.8      26.449
# 4             7.6      19.747
# ..            ...         ...
# 903           5.5      10.703
# 904           7.7      13.087
# 905           6.7      10.014
# 906           6.9      13.511
# 907           6.3      13.460
#
# [908 rows x 14 columns]

# %%
df10 = df.loc[(df['Year'] >= 2010)]

# %%
df10
# Out:
#       Rank                                       Title  Adj. Lifetime Gross  \
# 7       11  Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 11      16                           Avengers: Endgame         8.926696e+08
# 20      29                                The Avengers         7.203768e+08
# 21      30                              Jurassic World         7.195185e+08
# 22      31                               Black Panther         7.146714e+08
# ..     ...                                         ...                  ...
# 891    981                           The Peanuts Movie         1.402333e+08
# 895    986                        The Legend of Tarzan         1.394415e+08
# 900    991                     Lee Daniels' The Butler         1.387800e+08
# 901    992                             Horrible Bosses         1.387154e+08
# 907  1,000                        Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 7       936662200.0       108115100.0  2015  245000000.0
# 11      858373000.0        95268900.0  2019  356000000.0
# 20      623357900.0        76881200.0  2012  220000000.0
# 21      652270660.0        76789600.0  2015  150000000.0
# 22      700059600.0        76272300.0  2018  202003950.0
# ..              ...               ...   ...          ...
# 891     130178410.0        14966200.0  2015   99000000.0
# 895     126643064.0        14881700.0  2016  180000000.0
# 900     116632100.0        14811100.0  2013   30000000.0
# 901     117538560.0        14804200.0  2011   35000000.0
# 907     127440870.0        14740200.0  2016   50000000.0
#
#                      Director  \
# 7                 J.J. Abrams
# 11   Anthony Russo, Joe Russo
# 20                Joss Whedon
# 21            Colin Trevorrow
# 22               Ryan Coogler
# ..                        ...
# 891             Steve Martino
# 895               David Yates
# 900               Lee Daniels
# 901               Seth Gordon
# 907   Rawson Marshall Thurber
#
#                                                  Actor  \
# 7    Daisy Ridley, John Boyega, Oscar Isaac, Domhna...
# 11   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 20   Robert Downey Jr., Chris Evans, Scarlett Johan...
# 21   Chris Pratt, Bryce Dallas Howard, Ty Simpkins,...
# 22   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# ..                                                 ...
# 891  Noah Schnapp, Bill Melendez, Hadley Belle Mill...
# 895  Alexander SkarsgÃÃÃ¥Â«rd, Rory J. Saper, Chr...
# 900  Forest Whitaker, Oprah Winfrey, John Cusack, J...
# 901  Jason Bateman, Charlie Day, Jason Sudeikis, St...
# 907  Dwayne Johnson, Kevin Hart, Danielle Nicolet, ...
#
#                                            Genre    IMDB ID  Vote Count  \
# 7                      Action, Adventure, Sci-Fi  tt2488496       13865
# 11              Action, Adventure, Drama, Sci-Fi  tt4154796       11389
# 20                     Action, Adventure, Sci-Fi  tt0848228       21584
# 21                     Action, Adventure, Sci-Fi  tt0369610       15085
# 22                     Action, Adventure, Sci-Fi  tt1825683       14336
# ..                                           ...        ...         ...
# 891  Adventure, Animation, Comedy, Drama, Family  tt2452042         981
# 895   Action, Adventure, Drama, Fantasy, Romance  tt0918940        4463
# 900                             Biography, Drama  tt1327773        2031
# 901                                Comedy, Crime  tt1499658        4232
# 907                        Action, Comedy, Crime  tt1489889        3561
#
#      Vote Average  Popularity
# 7             7.4      28.812
# 11            8.3      38.570
# 20            7.7      37.337
# 21            6.6      25.921
# 22            7.4      34.269
# ..            ...         ...
# 891           6.6      10.825
# 895           5.8      16.242
# 900           7.4       9.582
# 901           6.5      11.970
# 907           6.3      13.460
#
# [238 rows x 14 columns]

# %%
directors = list(df['Director'])

# %%
directors
# Out:
# ['George Lucas',
#  'Robert Wise',
#  'Steven Spielberg',
#  'James Cameron',
#  'Steven Spielberg',
#  'William Friedkin',
#  'William Cottrell, David Hand, Wilfred Jackson, Larry Morey, Perce Pearce, Ben Sharpsteen',
#  'J.J. Abrams',
#  'Irvin Kershner',
#  'William Wyler',
#  'James Cameron',
#  'Anthony Russo, Joe Russo',
#  'Richard Marquand',
#  'Steven Spielberg',
#  'George Lucas',
#  'Roger Allers, Rob Minkoff',
#  'Steven Spielberg',
#  'Francis Ford Coppola',
#  'Robert Zemeckis',
#  'Randal Kleiser',
#  'Joss Whedon',
#  'Colin Trevorrow',
#  'Ryan Coogler',
#  'Christopher Nolan',
#  'Anthony Russo, Joe Russo',
#  'Ivan Reitman',
#  'Andrew Adamson, Kelly Asbury, Conrad Vernon',
#  'Sam Raimi',
#  'Roland Emmerich',
#  'Chris Columbus',
#  'Rian Johnson',
#  'Joseph L. Mankiewicz',
#  'Martin Brest',
#  'Brad Bird',
#  'George Seaton, Henry Hathaway',
#  'Henry Koster',
#  'Gore Verbinski',
#  'Michael Anderson, John Farrow',
#  'Tim Burton',
#  'Peter Jackson',
#  'Andrew Stanton, Lee Unkrich',
#  'John Guillermin',
#  'Gareth Edwards',
#  'Jon Favreau',
#  'Sam Raimi',
#  'George Cukor',
#  'Cecil B. DeMille',
#  'John Landis',
#  'Mel Gibson',
#  'George Lucas',
#  'Robert Zemeckis',
#  'Peter Jackson',
#  'Christopher Nolan',
#  'M. Night Shyamalan',
#  'Richard Donner',
#  'Sydney Pollack',
#  'Bill Condon',
#  'Andrew Stanton, Angus MacLane',
#  'Chris Columbus',
#  'Jerome Robbins, Robert Wise',
#  'Steven Spielberg',
#  'Clyde Geronimi, Wilfred Jackson, Hamilton Luske',
#  'J.J. Abrams',
#  'Ronald Neame',
#  'Peter Jackson',
#  'Jan de Bont',
#  'Barry Sonnenfeld',
#  'David Lean',
#  'Michael Bay',
#  'Stanley Kramer, William T. Hurtz, Bill Melendez',
#  'Milos Forman',
#  'Robert Altman',
#  'Steven Spielberg',
#  'George Lucas',
#  'Joss Whedon',
#  'Lee Unkrich',
#  'Chris Columbus, Chuck Jones',
#  'Ron Clements, John Musker',
#  'Jerry Zucker',
#  'Francis Lawrence',
#  'King Vidor, Otto Brower, William Dieterle, Sidney Franklin, William Cameron Menzies, David O. Selznick, Josef von Sternberg',
#  'Chris Buck, Jennifer Lee',
#  'Gary Ross',
#  'Gore Verbinski',
#  'AndrÃ\x8cÃ\x8eÃ¥Â© De Toth',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Pete Docter, David Silverman, Lee Unkrich',
#  'Chris Buck, Jennifer Lee',
#  'Sam Raimi',
#  'Shane Black',
#  'James Cameron',
#  'David Yates',
#  'Josh Cooley',
#  'Howard Hawks',
#  'Ron Howard',
#  'Tony Scott',
#  'John Lasseter',
#  'John Lasseter, Ash Brannon, Lee Unkrich',
#  'Anna Boden, Ryan Fleck',
#  'Andrew Adamson, Vicky Jenson',
#  'Chris Miller, Raman Hui',
#  'Pierre Coffin, Chris Renaud',
#  'Anthony Russo, Joe Russo',
#  'Lana Wachowski, Lilly Wachowski',
#  'Michael Bay',
#  'Peter Faiman',
#  'Patty Jenkins',
#  'J.A. Bayona',
#  'Rex Ingram',
#  'Steven Spielberg',
#  'Mel Brooks',
#  'Clyde Geronimi, Wilfred Jackson, Hamilton Luske, Jack Kinney',
#  'Joe Dante',
#  'Mike Newell',
#  'Gary Trousdale, Kirk Wise',
#  'Andrew Adamson',
#  'Chris Columbus',
#  'Gore Verbinski',
#  'Andrew Davis',
#  'Jon Favreau',
#  'Michael Bay',
#  'Jay Roach',
#  'Steven Spielberg',
#  'Jake Kasdan',
#  'Stanley Kubrick',
#  'Kevin Costner',
#  'Taylor Hackford',
#  'James Gunn',
#  'Jon Watts',
#  'Barry Levinson',
#  'Chris Renaud, Yarrow Cheney',
#  'Stanley Kramer',
#  'Clint Eastwood',
#  'Michael Bay',
#  'Alfred Hitchcock',
#  'David Yates',
#  'Pete Docter, Ronnie Del Carmen',
#  'Sylvester Stallone',
#  'George P. Cosmatos',
#  'Joel Schumacher',
#  'Tim Miller',
#  'Garry Marshall',
#  'Mark Robson',
#  'Tim Burton',
#  'Brad Bird',
#  'Robert Zemeckis',
#  'Chris Columbus',
#  'Jon Favreau',
#  'Leonard Nimoy',
#  'Joel Zwick',
#  'James Gunn',
#  'James Wan',
#  'Brian De Palma',
#  'Francis Lawrence',
#  'Kyle Balda, Pierre Coffin',
#  'David Yates',
#  'John Badham',
#  'Mark Rydell',
#  'Jay Roach',
#  'Alfonso CuarÃ\x8cÃ\x8e_n',
#  'Tom Shadyac',
#  'John Woo',
#  'Brett Ratner',
#  'Ron Howard',
#  'Franklin J. Schaffner',
#  'Adrian Lyne',
#  'Jon Favreau',
#  'Byron Howard, Rich Moore, Jared Bush',
#  'Tom Shadyac',
#  'Guy Ritchie',
#  'Kevin Reynolds',
#  'Tony Scott',
#  'Pete Docter, Bob Peterson',
#  'Tim Burton',
#  'M. Night Shyamalan',
#  'Chris Weitz',
#  'David Slade',
#  'Richard Lester, Richard Donner',
#  'Colin Higgins',
#  'Zack Snyder',
#  'Sydney Pollack',
#  'David Ayer',
#  'Robert Zemeckis, Richard Williams',
#  'Christopher Nolan',
#  'Sam Mendes',
#  'Peter Jackson',
#  'Bob Clark',
#  'Wolfgang Petersen',
#  'Sidney Poitier',
#  'Bobby Farrelly, Peter Farrelly',
#  'Jon Watts',
#  'John Lasseter, Joe Ranft',
#  'David Yates',
#  'Todd Phillips',
#  'James Wan',
#  'Richard Donner',
#  'Shawn Levy',
#  'Francis Lawrence',
#  'Jay Roach',
#  'Steven Spielberg',
#  'Andy Muschietti',
#  'James Fargo',
#  'Bill Condon',
#  'Bill Condon',
#  'Todd Phillips',
#  'Brett Ratner',
#  'Stephen Sommers',
#  'Bryan Singer',
#  'Oliver Stone',
#  'Sylvester Stallone',
#  'Zack Snyder',
#  'Michael Bay',
#  'James Cameron',
#  'Warren Beatty, Buck Henry',
#  'Richard Donner',
#  'Amy Heckerling',
#  'Ridley Scott',
#  'Jeannot Szwarc',
#  'David Leitch',
#  'J.J. Abrams',
#  'John Pasquin',
#  'Stuart Rosenberg',
#  'Taika Waititi',
#  'Frank Coraci',
#  'John Lasseter, Andrew Stanton',
#  'Rob Reiner',
#  'Sylvester Stallone',
#  'Cameron Crowe',
#  'Barry Sonnenfeld',
#  'Wolfgang Petersen',
#  'Peter Jackson',
#  'Lana Wachowski, Lilly Wachowski',
#  'Marc Webb',
#  'Chris Buck, Kevin Lima',
#  'Emile Ardolino',
#  'Jake Kasdan',
#  'John Lee Hancock',
#  'Ron Howard',
#  'Dan Scanlon',
#  'Nancy Meyers',
#  'Paul Greengrass',
#  'Alfonso CuarÃ\x8cÃ\x8e_n',
#  'Joe Johnston',
#  'James L. Brooks',
#  'Robert Wise',
#  'David Dobkin',
#  'Pierre Coffin, Chris Renaud',
#  'Mike Gabriel, Eric Goldberg',
#  'Steve Gordon',
#  'Francis Lawrence',
#  'Christopher Miller, Phil Lord',
#  'Christopher Nolan',
#  'Francis Ford Coppola',
#  'Tim Burton',
#  'Dennis Dugan',
#  'Steven Soderbergh',
#  'Joe Johnston',
#  'Steve Barron',
#  'Ridley Scott',
#  'Tim Burton',
#  'Peter Berg',
#  'James L. Brooks',
#  'Todd Phillips',
#  'Peter Jackson',
#  'Brian Levant',
#  'Anthony Russo, Joe Russo',
#  'John Landis',
#  'Jon Turteltaub',
#  'Andrew Stanton',
#  'Peter Jackson',
#  'Jonathan Demme',
#  'John G. Avildsen',
#  'Jim Abrahams, David Zucker, Jerry Zucker',
#  'Tim Hill',
#  'Jay Roach',
#  'Ron Howard',
#  'Betty Thomas',
#  'Ivan Reitman',
#  'Garth Jennings',
#  'Nora Ephron',
#  'Zack Snyder',
#  'Stephen Sommers',
#  'Bryan Singer',
#  'Stephen Herek',
#  'Michael Bay',
#  'Chris Wedge, Carlos Saldanha',
#  'Michael Bay',
#  'Mike Mitchell',
#  'Eric Darnell, Tom McGrath',
#  'Barry Levinson',
#  'Roland Emmerich',
#  'George Miller, Warren Coleman, Judy Morris',
#  'Brad Bird, Jan Pinkava',
#  'Mark Osborne, John Stevenson',
#  'Yarrow Cheney, Scott Mosier',
#  'Garry Marshall',
#  'Mark Andrews, Brenda Chapman, Steve Purcell',
#  'Mimi Leder',
#  'Rob Marshall',
#  'Brett Ratner',
#  'Blake Edwards',
#  'Carlos Saldanha',
#  'Peter Farrelly, Bobby Farrelly',
#  'Robert Zemeckis',
#  'Kyle Balda, Pierre Coffin, Eric Guillon',
#  'Robert Zemeckis',
#  'Gus Van Sant',
#  'Adrian Lyne',
#  'Ron Underwood',
#  'Mick Jackson',
#  'Ron Howard',
#  'Carl Reiner',
#  'Penelope Spheeris',
#  'Sam Raimi',
#  'Phillip Noyce',
#  'Bryan Singer',
#  'Ridley Scott',
#  'Robert Stromberg',
#  'Tom Shadyac',
#  'Keenen Ivory Wayans',
#  'Doug Liman',
#  'Roland Emmerich',
#  'Jan de Bont',
#  'Leonard Nimoy',
#  'John McTiernan',
#  'Robert Zemeckis',
#  'Jon Favreau',
#  'John Landis',
#  'Chuck Russell',
#  'Steven Spielberg',
#  'Richard Donner',
#  'Justin Lin',
#  'Paul Greengrass',
#  'Paul Verhoeven',
#  'Ivan Reitman',
#  'Rob Marshall',
#  'Betty Thomas',
#  'Ron Clements, John Musker, Don Hall, Chris Williams',
#  'Paul Verhoeven',
#  'Bryan Singer',
#  'Seth MacFarlane',
#  'Mike Nichols',
#  'Lewis Gilbert',
#  'Andy Tennant',
#  'Penny Marshall',
#  'Ivan Reitman',
#  'Richard Donner',
#  'Renny Harlin',
#  'Jon Turteltaub',
#  'P.J. Hogan',
#  'Daniel Myrick, Eduardo SÃ\x8cÃ\x8eÃ\x8cÂ\x81nchez',
#  'Dean DeBlois, Chris Sanders',
#  'Lee Tamahori',
#  'Steven Spielberg',
#  'J.J. Abrams',
#  'Tom Shadyac',
#  'John G. Avildsen',
#  'Barry Sonnenfeld',
#  'Catherine Hardwicke',
#  'Chris Renaud, Kyle Balda',
#  'Roger Spottiswoode',
#  'Eric Darnell, Tom McGrath, Conrad Vernon',
#  'Don Hall, Chris Williams',
#  'Guy Ritchie',
#  'Nicholas Meyer',
#  'Peter Weir',
#  'Rob Minkoff',
#  'David Silverman',
#  'David Yates',
#  'John Cornell',
#  'Rob Letterman, Conrad Vernon',
#  'Brad Bird',
#  'Steven Spielberg',
#  'Ron Clements, John Musker',
#  'Scott Derrickson',
#  'Raja Gosnell',
#  'Carlos Saldanha, Mike Thurmeier',
#  'Buddy Van Horn',
#  'Ridley Scott',
#  'Tobe Hooper',
#  'Frank Darabont',
#  'Justin Lin',
#  'Howard Zieff',
#  'Hal Needham',
#  'Penny Marshall',
#  'Bibo Bergeron, Vicky Jenson, Rob Letterman',
#  'Matt Reeves',
#  'Adrian Lyne',
#  'Tony Bancroft, Barry Cook',
#  'J.B. Rogers',
#  'James Mangold',
#  'Eric Leighton, Ralph Zondag',
#  'Rob Cohen',
#  'Walter Hill',
#  'Francis Ford Coppola',
#  'Martin Campbell',
#  'Quentin Tarantino',
#  'John Badham',
#  'F. Gary Gray',
#  'Bruce Beresford',
#  'Nathan Greno, Byron Howard',
#  'Ron Howard',
#  'Neil Jordan',
#  'Dean DeBlois, Chris Sanders',
#  'Eric Darnell, Tom McGrath',
#  'Marc Forster',
#  'Michael Apted',
#  'Zack Snyder',
#  'Jonathan Mostow',
#  'Sam Mendes',
#  'Christopher McQuarrie',
#  'Steve Oedekerk',
#  'Michael Apted',
#  'Alan Taylor',
#  'Wolfgang Petersen',
#  'John Guillermin',
#  'Peter Segal',
#  'Joel Schumacher',
#  'Alan Metter',
#  'Hal Needham',
#  'Peyton Reed',
#  'Warren Beatty',
#  'John Woo',
#  'Walt Becker',
#  'Rob Cohen',
#  'Martin Campbell',
#  'Clint Eastwood',
#  'Marc Webb',
#  'Gabriele Muccino',
#  'Richard Donner',
#  'Kenneth Branagh',
#  'Alan J. Pakula',
#  'Hugh Wilson',
#  'Peter Weir',
#  'Tim Story',
#  'Joseph Ruben',
#  'Gavin Hood',
#  'Gareth Edwards',
#  'Bryan Singer',
#  'John Lasseter, Bradford Lewis',
#  'Michael Lembeck',
#  'Hugh Wilson',
#  'Bradley Cooper',
#  'Nora Ephron',
#  'Herbert Ross',
#  'Shawn Levy',
#  'Guy Ritchie',
#  'Colin Higgins',
#  'Jon Turteltaub',
#  'Tim Johnson, Karey Kirkpatrick',
#  'Jonathan Liebesman',
#  'Ruben Fleischer',
#  'Christopher McQuarrie',
#  'Sydney Pollack',
#  'Rich Moore',
#  'Tony Scott',
#  'Marc Forster',
#  'Andy Muschietti',
#  'Rob Reiner',
#  'Joel Schumacher',
#  'Alex Proyas',
#  'Steven Soderbergh',
#  'Phil Lord, Christopher Miller',
#  'McG',
#  'Simon West',
#  'Lana Wachowski, Lilly Wachowski',
#  'Steven Spielberg',
#  'Brad Silberling',
#  'Sam Mendes',
#  'John McTiernan',
#  'Michael Bay',
#  'David Fincher',
#  'James Cameron',
#  'Bruce Beresford',
#  'Sam Weisman',
#  'Chuck Russell',
#  'Joe Johnston',
#  'Peter Segal',
#  'Lee Unkrich, Adrian Molina',
#  'Roger Michell',
#  'Ron Howard',
#  'Robert Zemeckis',
#  'Kirk DeMicco, Chris Sanders',
#  'Leonard Nimoy',
#  'Richard Attenborough',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Ang Lee',
#  'Christopher Nolan',
#  'Gary Trousdale, Kirk Wise',
#  'Adam McKay',
#  'Harald Zwart',
#  'Wes Craven',
#  'Peter Segal',
#  'Kenneth Branagh',
#  'Barry Sonnenfeld',
#  'Shawn Levy',
#  'Phil Johnston, Rich Moore',
#  'Rupert Wyatt',
#  'Joe Johnston',
#  'Gore Verbinski',
#  'Barry Sonnenfeld',
#  'Joel Schumacher',
#  'Simon West',
#  'Adam Shankman',
#  'Robert Zemeckis',
#  'Anne Fletcher',
#  'Steven Soderbergh',
#  'Ang Lee',
#  'Wes Craven',
#  'Andy Tennant',
#  'Peyton Reed',
#  'Raja Gosnell',
#  'Roland Emmerich',
#  'Steven Brill',
#  'Ivan Reitman',
#  'Ethan Coen, Joel Coen',
#  'Judd Apatow',
#  'Joseph Kosinski',
#  'Ron Clements, John Musker',
#  'John Glen',
#  'Jimmy Hayward, Steve Martino',
#  'Dean DeBlois',
#  'Wolfgang Petersen',
#  'Charles Shyer',
#  'Ron Howard',
#  'Boaz Yakin',
#  'Elizabeth Banks',
#  'Alejandro G. IÃ\x8cÃ\x8eÃ¥Â±Ã\x8cÃ\x8eÃ\x8cÂ\x81rritu',
#  'Tate Taylor',
#  'John Landis',
#  'Michael Patrick King',
#  'Christopher Nolan',
#  'Peter Yates',
#  'Curtis Hanson',
#  'Igor Kovalyov, Norton Virgien',
#  'Mark Dindal',
#  'Bob Persichetti, Peter Ramsey, Rodney Rothman',
#  'John Singleton',
#  'Adil El Arbi, Bilall Fallah',
#  'Danny DeVito',
#  'Harold Ramis',
#  'Roland Emmerich',
#  'Paul Feig',
#  'Dennis Dugan',
#  'Tony Scott',
#  'Frank Coraci',
#  'Doug Liman',
#  'Michael Cimino',
#  'Robert Zemeckis',
#  'Brenda Chapman, Steve Hickner, Simon Wells',
#  'Nora Ephron',
#  'Clint Eastwood',
#  'Michael Ritchie',
#  'Justin Lin',
#  'Ron Howard',
#  'Jonathan Frakes',
#  'Steve Martino, Mike Thurmeier',
#  'Lewis Teague',
#  'Louis Leterrier',
#  'David Zucker',
#  'Tim Johnson',
#  'Sylvester Stallone',
#  'Albert Magnoli',
#  'Stan Dragoti',
#  'Jennifer Yuh Nelson',
#  'Herbert Ross',
#  'Phil Alden Robinson',
#  'J.J. Abrams',
#  'Sam Taylor-Johnson',
#  'Quentin Tarantino',
#  'Bernardo Bertolucci',
#  'Alan J. Pakula',
#  'Joe Pytka',
#  'Brett Ratner',
#  'Robert Redford',
#  'Paul Feig',
#  'Renny Harlin',
#  'Nancy Meyers',
#  'Kevin Reynolds',
#  'John McTiernan',
#  'David Fincher',
#  'Simon West',
#  'Paul Weitz, Chris Weitz',
#  'Paul Brickman',
#  'Les Mayfield',
#  'Andrew Davis',
#  'Stephen Sommers',
#  'Martin Scorsese',
#  'John Carpenter',
#  'Phillip Noyce',
#  'Curtis Hanson',
#  'Jason Reitman',
#  'Phyllida Lloyd',
#  'Steven Soderbergh',
#  'Hugh Hudson',
#  'John Krasinski',
#  'Paul Tibbitt, Mike Mitchell',
#  'Chris Wedge, Carlos Saldanha',
#  'Martin Campbell',
#  'Steve Carr',
#  'Gary Ross',
#  'Robert Rodriguez',
#  'Francis Ford Coppola',
#  'Jordan Peele',
#  'Chris McKay',
#  'Clint Eastwood',
#  'Jon Avnet',
#  'John Madden',
#  'Peter Lord, Nick Park',
#  'Tim Burton',
#  'Jon M. Chu',
#  'Andrew Adamson',
#  'John Glen',
#  'Norman Jewison',
#  'Steve Carr',
#  'Larry Charles',
#  'Tom McGrath',
#  'Len Wiseman',
#  'Tony Scott',
#  'F. Gary Gray',
#  'John N. Smith',
#  'Genndy Tartakovsky',
#  'Brian De Palma',
#  'David Zucker',
#  'Harold Ramis',
#  'Peter Segal',
#  'Barry Levinson',
#  'Pierre Morel',
#  'Jordan Peele',
#  'John Huston',
#  'Clark Johnson',
#  'Peter Weir',
#  'Stephen Sommers',
#  'Eric Darnell, Tim Johnson',
#  'Jim Abrahams, David Zucker, Jerry Zucker',
#  'David Leitch',
#  'Joachim RÃ\x8cÃ\x8eÃ\x8c_nning, Espen Sandberg',
#  'David Frankel',
#  'Rupert Sanders',
#  'Michael Moore',
#  'Theodore Melfi',
#  'Tim Story',
#  'David Kellogg',
#  'Garry Marshall',
#  'Donald Petrie',
#  'Walter Hill',
#  'Rawson Marshall Thurber',
#  'Paul Greengrass',
#  'Rob Marshall',
#  'Chris Miller',
#  'David Frankel',
#  'Roger Donaldson',
#  'Richard Lester',
#  'Danny Boyle, Loveleen Tandan',
#  'Michael Gracey',
#  'Chad Stahelski',
#  'Jordan Vogt-Roberts',
#  'Genndy Tartakovsky',
#  'Ridley Scott',
#  'Brad Silberling',
#  'John Hughes',
#  'Martin Scorsese',
#  'Dominic Sena',
#  'Louis Leterrier',
#  'Simon Wincer',
#  'Timur Bekmambetov',
#  'Paul Weitz',
#  'Ridley Scott',
#  'Carl Reiner',
#  'Michael Pressman',
#  'Stephen Herek',
#  'Tom Hooper',
#  'Justin Lin',
#  'Jon Turteltaub',
#  'Frank Marshall',
#  'David O. Russell',
#  'James Mangold',
#  'Tom McGrath',
#  'Robert Rodriguez',
#  'Jonathan Demme',
#  'Robert Altman',
#  'Chris Columbus',
#  'Neil Burger',
#  'Ron Howard',
#  'Kevin Lima',
#  'Genndy Tartakovsky',
#  'Rawson Marshall Thurber',
#  'M. Night Shyamalan',
#  'Simon J. Smith, Steve Hickner',
#  'Ron Shelton',
#  'Mark Waters',
#  'David Zucker',
#  'Edward Zwick',
#  'Michael Mann',
#  'Matthew Vaughn',
#  'Peter Segal',
#  'Alan Alda',
#  'Peyton Reed',
#  'Brad Peyton',
#  'Robert Zemeckis',
#  'David Carson',
#  'Nicholas Stoller',
#  'Barbra Streisand',
#  'Jan de Bont',
#  'Tim Burton',
#  'Sam Mendes',
#  'Raja Gosnell',
#  'George Miller',
#  'Roger Spottiswoode',
#  'Nicholas Meyer',
#  'Rob Bowman',
#  'Ron Howard',
#  'George Scribner',
#  'Dean DeBlois',
#  'Carlos Saldanha',
#  'Bryan Singer',
#  'Takashi Shimizu',
#  'David Yates',
#  'Greg Mottola',
#  'David Gordon Green',
#  'Adam Shankman',
#  'Chris Renaud, Jonathan del Val',
#  'Jeremiah S. Chechik',
#  'Tom Hooper',
#  'F. Gary Gray',
#  'Irvin Kershner',
#  'Lawrence Kasdan',
#  'Cameron Crowe',
#  'M. Night Shyamalan',
#  'Rian Johnson',
#  'Donald Petrie',
#  'James Wan',
#  'Mike Mitchell, Walt Dohrn',
#  'Charles Shyer',
#  'Dennis Dugan',
#  'Sean Anders',
#  'Sidney Lumet',
#  'Olivier Megaton',
#  'Mel Gibson',
#  'Jesse Dylan',
#  'Anthony Minghella',
#  'Baz Luhrmann',
#  'Richard Donner',
#  'Steve Carr',
#  'Phil Lord, Christopher Miller',
#  'Adam Shankman',
#  'Tom Shadyac',
#  'Jon Amiel',
#  'Josh Gordon, Will Speck',
#  'David Fincher',
#  'Woody Allen',
#  'Ivan Reitman',
#  'Herbert Ross',
#  'Don Siegel',
#  'Harold Ramis',
#  'Roland Emmerich',
#  'Frank Coraci',
#  'Damien Chazelle',
#  'Brian Fee',
#  'M. Night Shyamalan',
#  'Judd Apatow',
#  'Alejandro AmenÃ\x8cÃ\x8eÃ\x8cÂ\x81bar',
#  'Robert Luketic',
#  'Dennis Dugan',
#  'Steven Soderbergh',
#  'Mark Steven Johnson',
#  'Dean Parisot',
#  'Emile Ardolino',
#  'Ben Affleck',
#  'Tim Story',
#  'Oliver Stone',
#  'Mike Mitchell',
#  'Seth Gordon',
#  'James Mangold',
#  'Reginald Hudlin',
#  'Kunihiko Yuyama, Michael Haigney',
#  'Mark Steven Johnson',
#  'John Hughes',
#  'Donald Petrie',
#  'Bobby Farrelly, Peter Farrelly',
#  'McG',
#  'John Badham',
#  'John Badham',
#  'Clint Eastwood',
#  'Brad Silberling',
#  'Richard Attenborough',
#  'Bo Welch',
#  'Paul Mazursky',
#  'Seth Gordon',
#  'McG',
#  'Alessandro Carloni, Jennifer Yuh Nelson',
#  'Richard Donner',
#  'Sam Mendes',
#  'Jon Turteltaub',
#  'David Fincher',
#  'David Breashears, Stephen Judson, Greg MacGillivray',
#  'Barry Sonnenfeld',
#  'David O. Russell',
#  'Oliver Stone',
#  'Richard Donner',
#  'Wes Craven',
#  'Joe Roth',
#  'John Landis',
#  'Jim Abrahams',
#  'Lawrence Guterman',
#  'Phil Lord, Christopher Miller',
#  'Jon Turteltaub',
#  'Stanley Kubrick',
#  'Matt Reeves',
#  'Clint Eastwood',
#  'George Miller',
#  'Michael Mann',
#  'Emile Ardolino',
#  'Howard Deutch',
#  'Phil Alden Robinson',
#  'Paul W.S. Anderson',
#  'Quentin Tarantino',
#  'Martin Scorsese',
#  'Martin Scorsese',
#  'Mark Dindal',
#  'Thomas Carter',
#  'Robert Redford',
#  'Ted Kotcheff',
#  'Brian Helgeland',
#  'Brett Ratner',
#  'Chris Columbus',
#  'John Woo',
#  'Hoyt Yeatman',
#  'Rob Letterman',
#  'Mike Nichols',
#  'Daniel Espinosa',
#  'Woody Allen',
#  'Clint Eastwood',
#  'Wayne Wang',
#  'Ivan Reitman',
#  'Francis Ford Coppola',
#  'Jim Gillespie',
#  'J.J. Abrams',
#  'Byron Howard, Chris Williams',
#  'Carlos Saldanha',
#  'Quentin Tarantino',
#  'Henry Selick',
#  'Michael Sucsy',
#  'Rob Marshall',
#  'Matthew Vaughn',
#  'Peter Berg',
#  'Clint Eastwood',
#  'Luc Besson',
#  'Chuck Russell',
#  'Gore Verbinski',
#  'Jerry Paris, James Signorelli',
#  'Marc Lawrence',
#  'Ridley Scott',
#  'M. Night Shyamalan',
#  'Stanley Kubrick',
#  'Adam McKay',
#  'Ang Lee',
#  'David F. Sandberg',
#  'Robert Schwentke',
#  'Wolfgang Petersen',
#  'Mike Nichols',
#  'Richard Donner',
#  'Peter Weir',
#  'Neill Blomkamp',
#  'Tommy Chong',
#  'Adam McKay',
#  'Anthony Minghella',
#  'Anthony Minghella',
#  'Ben Stiller',
#  'Michael Mann',
#  'Phillip Noyce',
#  'Garry Marshall',
#  'Edward Zwick',
#  'Ivan Reitman',
#  'John McTiernan',
#  'Philip Kaufman',
#  'Forest Whitaker',
#  'Martin Brest',
#  'Eddie Murphy',
#  'Charles Crichton, John Cleese',
#  'Bill Condon',
#  'Andrey Konchalovskiy, Albert Magnoli',
#  'Gary Ross',
#  'Frank Oz',
#  'Michael Bay',
#  'Neil Jordan',
#  'Paul Feig',
#  'Bob Fosse',
#  'Josh Boone',
#  'Steve Martino',
#  'Alan Parker',
#  'Charles Herman-Wurmfeld',
#  'Stephen Norrington',
#  'David Yates',
#  'Milos Forman',
#  'Gary Trousdale, Kirk Wise',
#  'Adam Shankman',
#  'Harold Ramis',
#  'Lee Daniels',
#  'Seth Gordon',
#  'Sean S. Cunningham',
#  'Robert Rodriguez',
#  'Clint Eastwood',
#  'Harold Becker',
#  'Richard Donner',
#  'Rawson Marshall Thurber']

# %%
df10 = df.loc[(df['Year'] >= 2010)]
df10
# Out:
#       Rank                                       Title  Adj. Lifetime Gross  \
# 7       11  Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 11      16                           Avengers: Endgame         8.926696e+08
# 20      29                                The Avengers         7.203768e+08
# 21      30                              Jurassic World         7.195185e+08
# 22      31                               Black Panther         7.146714e+08
# ..     ...                                         ...                  ...
# 891    981                           The Peanuts Movie         1.402333e+08
# 895    986                        The Legend of Tarzan         1.394415e+08
# 900    991                     Lee Daniels' The Butler         1.387800e+08
# 901    992                             Horrible Bosses         1.387154e+08
# 907  1,000                        Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 7       936662200.0       108115100.0  2015  245000000.0
# 11      858373000.0        95268900.0  2019  356000000.0
# 20      623357900.0        76881200.0  2012  220000000.0
# 21      652270660.0        76789600.0  2015  150000000.0
# 22      700059600.0        76272300.0  2018  202003950.0
# ..              ...               ...   ...          ...
# 891     130178410.0        14966200.0  2015   99000000.0
# 895     126643064.0        14881700.0  2016  180000000.0
# 900     116632100.0        14811100.0  2013   30000000.0
# 901     117538560.0        14804200.0  2011   35000000.0
# 907     127440870.0        14740200.0  2016   50000000.0
#
#                      Director  \
# 7                 J.J. Abrams
# 11   Anthony Russo, Joe Russo
# 20                Joss Whedon
# 21            Colin Trevorrow
# 22               Ryan Coogler
# ..                        ...
# 891             Steve Martino
# 895               David Yates
# 900               Lee Daniels
# 901               Seth Gordon
# 907   Rawson Marshall Thurber
#
#                                                  Actor  \
# 7    Daisy Ridley, John Boyega, Oscar Isaac, Domhna...
# 11   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 20   Robert Downey Jr., Chris Evans, Scarlett Johan...
# 21   Chris Pratt, Bryce Dallas Howard, Ty Simpkins,...
# 22   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# ..                                                 ...
# 891  Noah Schnapp, Bill Melendez, Hadley Belle Mill...
# 895  Alexander SkarsgÃÃÃ¥Â«rd, Rory J. Saper, Chr...
# 900  Forest Whitaker, Oprah Winfrey, John Cusack, J...
# 901  Jason Bateman, Charlie Day, Jason Sudeikis, St...
# 907  Dwayne Johnson, Kevin Hart, Danielle Nicolet, ...
#
#                                            Genre    IMDB ID  Vote Count  \
# 7                      Action, Adventure, Sci-Fi  tt2488496       13865
# 11              Action, Adventure, Drama, Sci-Fi  tt4154796       11389
# 20                     Action, Adventure, Sci-Fi  tt0848228       21584
# 21                     Action, Adventure, Sci-Fi  tt0369610       15085
# 22                     Action, Adventure, Sci-Fi  tt1825683       14336
# ..                                           ...        ...         ...
# 891  Adventure, Animation, Comedy, Drama, Family  tt2452042         981
# 895   Action, Adventure, Drama, Fantasy, Romance  tt0918940        4463
# 900                             Biography, Drama  tt1327773        2031
# 901                                Comedy, Crime  tt1499658        4232
# 907                        Action, Comedy, Crime  tt1489889        3561
#
#      Vote Average  Popularity
# 7             7.4      28.812
# 11            8.3      38.570
# 20            7.7      37.337
# 21            6.6      25.921
# 22            7.4      34.269
# ..            ...         ...
# 891           6.6      10.825
# 895           5.8      16.242
# 900           7.4       9.582
# 901           6.5      11.970
# 907           6.3      13.460
#
# [238 rows x 14 columns]

# %%
directors_list = list(df['Director'])
directors_list
directors_list2 = ','.join(directors_list)

# %%
directors_list = list(df10['Director'])
directors_list
directors_list2 = ','.join(directors_list)

# %%
directors_list2
# Out:
# 'J.J. Abrams,Anthony Russo, Joe Russo,Joss Whedon,Colin Trevorrow,Ryan Coogler,Anthony Russo, Joe Russo,Rian Johnson,Brad Bird,Gareth Edwards,Jon Favreau,Christopher Nolan,Bill Condon,Andrew Stanton, Angus MacLane,J.J. Abrams,Joss Whedon,Lee Unkrich,Francis Lawrence,Chris Buck, Jennifer Lee,Gary Ross,Chris Buck, Jennifer Lee,Shane Black,David Yates,Josh Cooley,Anna Boden, Ryan Fleck,Pierre Coffin, Chris Renaud,Anthony Russo, Joe Russo,Patty Jenkins,J.A. Bayona,Michael Bay,Jake Kasdan,James Gunn,Jon Watts,Chris Renaud, Yarrow Cheney,Clint Eastwood,Pete Docter, Ronnie Del Carmen,Tim Miller,Tim Burton,Jon Favreau,James Gunn,James Wan,Francis Lawrence,Kyle Balda, Pierre Coffin,Jon Favreau,Byron Howard, Rich Moore, Jared Bush,Guy Ritchie,David Slade,Zack Snyder,David Ayer,Christopher Nolan,Sam Mendes,Peter Jackson,Jon Watts,David Yates,James Wan,Andy Muschietti,Bill Condon,Bill Condon,Todd Phillips,Zack Snyder,David Leitch,Taika Waititi,Marc Webb,Jake Kasdan,Dan Scanlon,Alfonso CuarÃ\x8cÃ\x8e_n,Pierre Coffin, Chris Renaud,Francis Lawrence,Christopher Miller, Phil Lord,Todd Phillips,Peter Jackson,Anthony Russo, Joe Russo,Peter Jackson,Garth Jennings,Michael Bay,Mike Mitchell,Yarrow Cheney, Scott Mosier,Mark Andrews, Brenda Chapman, Steve Purcell,Rob Marshall,Kyle Balda, Pierre Coffin, Eric Guillon,Sam Raimi,Robert Stromberg,Justin Lin,Ron Clements, John Musker, Don Hall, Chris Williams,Bryan Singer,Seth MacFarlane,Dean DeBlois, Chris Sanders,J.J. Abrams,Chris Renaud, Kyle Balda,Eric Darnell, Tom McGrath, Conrad Vernon,Don Hall, Chris Williams,David Yates,Brad Bird,Scott Derrickson,Ridley Scott,Justin Lin,Matt Reeves,James Mangold,F. Gary Gray,Nathan Greno, Byron Howard,Marc Forster,Zack Snyder,Christopher McQuarrie,Alan Taylor,Peyton Reed,Marc Webb,Kenneth Branagh,Gareth Edwards,Bryan Singer,John Lasseter, Bradford Lewis,Bradley Cooper,Guy Ritchie,Jonathan Liebesman,Ruben Fleischer,Christopher McQuarrie,Rich Moore,Andy Muschietti,Phil Lord, Christopher Miller,Sam Mendes,Lee Unkrich, Adrian Molina,Ron Howard,Kirk DeMicco, Chris Sanders,Steven Spielberg,Christopher Nolan,Harald Zwart,Kenneth Branagh,Phil Johnston, Rich Moore,Rupert Wyatt,Joe Johnston,Barry Sonnenfeld,Peyton Reed,Ethan Coen, Joel Coen,Joseph Kosinski,Dean DeBlois,Elizabeth Banks,Alejandro G. IÃ\x8cÃ\x8eÃ¥Â±Ã\x8cÃ\x8eÃ\x8cÂ\x81rritu,Tate Taylor,Christopher Nolan,Bob Persichetti, Peter Ramsey, Rodney Rothman,Adil El Arbi, Bilall Fallah,Paul Feig,Dennis Dugan,Steve Martino, Mike Thurmeier,Louis Leterrier,Tim Johnson,Jennifer Yuh Nelson,Sam Taylor-Johnson,Quentin Tarantino,Paul Feig,David Fincher,John Krasinski,Paul Tibbitt, Mike Mitchell,Jordan Peele,Chris McKay,Jon M. Chu,Tom McGrath,F. Gary Gray,Genndy Tartakovsky,Jordan Peele,David Leitch,Joachim RÃ\x8cÃ\x8eÃ\x8c_nning, Espen Sandberg,Rupert Sanders,Theodore Melfi,Rawson Marshall Thurber,Paul Greengrass,Rob Marshall,Chris Miller,Michael Gracey,Chad Stahelski,Jordan Vogt-Roberts,Genndy Tartakovsky,Paul Weitz,Tom Hooper,Justin Lin,David O. Russell,Tom McGrath,Neil Burger,Genndy Tartakovsky,Matthew Vaughn,Brad Peyton,Nicholas Stoller,Raja Gosnell,George Miller,Dean DeBlois,Carlos Saldanha,Bryan Singer,David Yates,David Gordon Green,Chris Renaud, Jonathan del Val,Tom Hooper,Rian Johnson,James Wan,Mike Mitchell, Walt Dohrn,Sean Anders,Olivier Megaton,Baz Luhrmann,Phil Lord, Christopher Miller,Damien Chazelle,Brian Fee,M. Night Shyamalan,Dennis Dugan,Ben Affleck,Tim Story,Mike Mitchell,Seth Gordon,James Mangold,Alessandro Carloni, Jennifer Yuh Nelson,Sam Mendes,David O. Russell,Jon Turteltaub,Matt Reeves,Martin Scorsese,Rob Letterman,Daniel Espinosa,J.J. Abrams,Carlos Saldanha,Quentin Tarantino,Michael Sucsy,Rob Marshall,Matthew Vaughn,Peter Berg,Luc Besson,Gore Verbinski,Ridley Scott,M. Night Shyamalan,Adam McKay,Ang Lee,David F. Sandberg,Robert Schwentke,Adam McKay,Phillip Noyce,Gary Ross,Paul Feig,Josh Boone,Steve Martino,David Yates,Lee Daniels,Seth Gordon,Rawson Marshall Thurber'

# %%
directors_list3 = directors_list2.replace(",",", ")

# %%
directors_list4 = directors_list3.replace("  ","")

# %%
directors_list5 = directors_list4.replace(",",", ")

# %%
directors_list6 = directors_list5.replace("  "," ")

# %%
directors_list6
# Out:
# 'J.J. Abrams, Anthony Russo, Joe Russo, Joss Whedon, Colin Trevorrow, Ryan Coogler, Anthony Russo, Joe Russo, Rian Johnson, Brad Bird, Gareth Edwards, Jon Favreau, Christopher Nolan, Bill Condon, Andrew Stanton, Angus MacLane, J.J. Abrams, Joss Whedon, Lee Unkrich, Francis Lawrence, Chris Buck, Jennifer Lee, Gary Ross, Chris Buck, Jennifer Lee, Shane Black, David Yates, Josh Cooley, Anna Boden, Ryan Fleck, Pierre Coffin, Chris Renaud, Anthony Russo, Joe Russo, Patty Jenkins, J.A. Bayona, Michael Bay, Jake Kasdan, James Gunn, Jon Watts, Chris Renaud, Yarrow Cheney, Clint Eastwood, Pete Docter, Ronnie Del Carmen, Tim Miller, Tim Burton, Jon Favreau, James Gunn, James Wan, Francis Lawrence, Kyle Balda, Pierre Coffin, Jon Favreau, Byron Howard, Rich Moore, Jared Bush, Guy Ritchie, David Slade, Zack Snyder, David Ayer, Christopher Nolan, Sam Mendes, Peter Jackson, Jon Watts, David Yates, James Wan, Andy Muschietti, Bill Condon, Bill Condon, Todd Phillips, Zack Snyder, David Leitch, Taika Waititi, Marc Webb, Jake Kasdan, Dan Scanlon, Alfonso CuarÃ\x8cÃ\x8e_n, Pierre Coffin, Chris Renaud, Francis Lawrence, Christopher Miller, Phil Lord, Todd Phillips, Peter Jackson, Anthony Russo, Joe Russo, Peter Jackson, Garth Jennings, Michael Bay, Mike Mitchell, Yarrow Cheney, Scott Mosier, Mark Andrews, Brenda Chapman, Steve Purcell, Rob Marshall, Kyle Balda, Pierre Coffin, Eric Guillon, Sam Raimi, Robert Stromberg, Justin Lin, Ron Clements, John Musker, Don Hall, Chris Williams, Bryan Singer, Seth MacFarlane, Dean DeBlois, Chris Sanders, J.J. Abrams, Chris Renaud, Kyle Balda, Eric Darnell, Tom McGrath, Conrad Vernon, Don Hall, Chris Williams, David Yates, Brad Bird, Scott Derrickson, Ridley Scott, Justin Lin, Matt Reeves, James Mangold, F. Gary Gray, Nathan Greno, Byron Howard, Marc Forster, Zack Snyder, Christopher McQuarrie, Alan Taylor, Peyton Reed, Marc Webb, Kenneth Branagh, Gareth Edwards, Bryan Singer, John Lasseter, Bradford Lewis, Bradley Cooper, Guy Ritchie, Jonathan Liebesman, Ruben Fleischer, Christopher McQuarrie, Rich Moore, Andy Muschietti, Phil Lord, Christopher Miller, Sam Mendes, Lee Unkrich, Adrian Molina, Ron Howard, Kirk DeMicco, Chris Sanders, Steven Spielberg, Christopher Nolan, Harald Zwart, Kenneth Branagh, Phil Johnston, Rich Moore, Rupert Wyatt, Joe Johnston, Barry Sonnenfeld, Peyton Reed, Ethan Coen, Joel Coen, Joseph Kosinski, Dean DeBlois, Elizabeth Banks, Alejandro G. IÃ\x8cÃ\x8eÃ¥Â±Ã\x8cÃ\x8eÃ\x8cÂ\x81rritu, Tate Taylor, Christopher Nolan, Bob Persichetti, Peter Ramsey, Rodney Rothman, Adil El Arbi, Bilall Fallah, Paul Feig, Dennis Dugan, Steve Martino, Mike Thurmeier, Louis Leterrier, Tim Johnson, Jennifer Yuh Nelson, Sam Taylor-Johnson, Quentin Tarantino, Paul Feig, David Fincher, John Krasinski, Paul Tibbitt, Mike Mitchell, Jordan Peele, Chris McKay, Jon M. Chu, Tom McGrath, F. Gary Gray, Genndy Tartakovsky, Jordan Peele, David Leitch, Joachim RÃ\x8cÃ\x8eÃ\x8c_nning, Espen Sandberg, Rupert Sanders, Theodore Melfi, Rawson Marshall Thurber, Paul Greengrass, Rob Marshall, Chris Miller, Michael Gracey, Chad Stahelski, Jordan Vogt-Roberts, Genndy Tartakovsky, Paul Weitz, Tom Hooper, Justin Lin, David O. Russell, Tom McGrath, Neil Burger, Genndy Tartakovsky, Matthew Vaughn, Brad Peyton, Nicholas Stoller, Raja Gosnell, George Miller, Dean DeBlois, Carlos Saldanha, Bryan Singer, David Yates, David Gordon Green, Chris Renaud, Jonathan del Val, Tom Hooper, Rian Johnson, James Wan, Mike Mitchell, Walt Dohrn, Sean Anders, Olivier Megaton, Baz Luhrmann, Phil Lord, Christopher Miller, Damien Chazelle, Brian Fee, M. Night Shyamalan, Dennis Dugan, Ben Affleck, Tim Story, Mike Mitchell, Seth Gordon, James Mangold, Alessandro Carloni, Jennifer Yuh Nelson, Sam Mendes, David O. Russell, Jon Turteltaub, Matt Reeves, Martin Scorsese, Rob Letterman, Daniel Espinosa, J.J. Abrams, Carlos Saldanha, Quentin Tarantino, Michael Sucsy, Rob Marshall, Matthew Vaughn, Peter Berg, Luc Besson, Gore Verbinski, Ridley Scott, M. Night Shyamalan, A ...

# %%
word_directors = directors_list6.replace(" ","")

# %%
director_list = directors_list6.split(", ")

# %%
director_list = list(set(director_list))

# %%
len(director_list)
# Out:
# 180

# %%
director_list
# Out:
# ['Phil Johnston',
#  'David Slade',
#  'Genndy Tartakovsky',
#  'Peter Ramsey',
#  'Nathan Greno',
#  'Anna Boden',
#  'Ron Howard',
#  'Rian Johnson',
#  'Steve Purcell',
#  'Bradford Lewis',
#  'Barry Sonnenfeld',
#  'David O. Russell',
#  'Marc Webb',
#  'John Krasinski',
#  'Peter Jackson',
#  'Angus MacLane',
#  'Ridley Scott',
#  'Jonathan Liebesman',
#  'Zack Snyder',
#  'Eric Guillon',
#  'Bob Persichetti',
#  'Scott Mosier',
#  'Shane Black',
#  'Eric Darnell',
#  'Tim Johnson',
#  'Tim Miller',
#  'Baz Luhrmann',
#  'Patty Jenkins',
#  'David Yates',
#  'Brad Bird',
#  'Alfonso CuarÃ\x8cÃ\x8e_n',
#  'Chris Williams',
#  'Rob Marshall',
#  'John Lasseter',
#  'David Fincher',
#  'Rupert Wyatt',
#  'George Miller',
#  'Rob Letterman',
#  'Joseph Kosinski',
#  'Chris Buck',
#  'Chris Sanders',
#  'Gary Ross',
#  'Byron Howard',
#  'Paul Feig',
#  'Peyton Reed',
#  'Colin Trevorrow',
#  'Tate Taylor',
#  'Jake Kasdan',
#  'Louis Leterrier',
#  'Tom Hooper',
#  'Mike Thurmeier',
#  'Jennifer Yuh Nelson',
#  'Raja Gosnell',
#  'Don Hall',
#  'Espen Sandberg',
#  'J.A. Bayona',
#  'Olivier Megaton',
#  'Ryan Fleck',
#  'Ang Lee',
#  'Garth Jennings',
#  'David Gordon Green',
#  'Todd Phillips',
#  'Adam McKay',
#  'Christopher McQuarrie',
#  'Dean DeBlois',
#  'Pete Docter',
#  'Scott Derrickson',
#  'Robert Schwentke',
#  'Phil Lord',
#  'Matt Reeves',
#  'John Musker',
#  'Seth MacFarlane',
#  'Walt Dohrn',
#  'Paul Tibbitt',
#  'David Leitch',
#  'Bradley Cooper',
#  'J.J. Abrams',
#  'Damien Chazelle',
#  'Joss Whedon',
#  'David F. Sandberg',
#  'Peter Berg',
#  'Kirk DeMicco',
#  'Adrian Molina',
#  'Alan Taylor',
#  'Justin Lin',
#  'Rodney Rothman',
#  'Quentin Tarantino',
#  'Ron Clements',
#  'Guy Ritchie',
#  'Jordan Vogt-Roberts',
#  'Marc Forster',
#  'Jordan Peele',
#  'Anthony Russo',
#  'Gareth Edwards',
#  'Paul Greengrass',
#  'Jon Turteltaub',
#  'Joe Russo',
#  'Bilall Fallah',
#  'Ethan Coen',
#  'Chris McKay',
#  'Sean Anders',
#  'Sam Taylor-Johnson',
#  'Chris Renaud',
#  'Mike Mitchell',
#  'Jon M. Chu',
#  'Rawson Marshall Thurber',
#  'Carlos Saldanha',
#  'Luc Besson',
#  'James Wan',
#  'Lee Unkrich',
#  'Kenneth Branagh',
#  'Steven Spielberg',
#  'Adil El Arbi',
#  'Francis Lawrence',
#  'Phillip Noyce',
#  'Ben Affleck',
#  'Michael Bay',
#  'Andrew Stanton',
#  'Jon Favreau',
#  'David Ayer',
#  'F. Gary Gray',
#  'Alessandro Carloni',
#  'Bill Condon',
#  'Yarrow Cheney',
#  'Jon Watts',
#  'Conrad Vernon',
#  'Harald Zwart',
#  'Theodore Melfi',
#  'Elizabeth Banks',
#  'Brenda Chapman',
#  'Kyle Balda',
#  'Daniel Espinosa',
#  'Joachim RÃ\x8cÃ\x8eÃ\x8c_nning',
#  'Ruben Fleischer',
#  'Josh Cooley',
#  'Taika Waititi',
#  'Dan Scanlon',
#  'Rich Moore',
#  'Christopher Nolan',
#  'M. Night Shyamalan',
#  'Andy Muschietti',
#  'Pierre Coffin',
#  'Clint Eastwood',
#  'Michael Sucsy',
#  'Ryan Coogler',
#  'Mark Andrews',
#  'Steve Martino',
#  'Michael Gracey',
#  'Seth Gordon',
#  'Jonathan del Val',
#  'Sam Raimi',
#  'Ronnie Del Carmen',
#  'Joe Johnston',
#  'Matthew Vaughn',
#  'Jennifer Lee',
#  'Rupert Sanders',
#  'Lee Daniels',
#  'James Mangold',
#  'Tim Burton',
#  'Gore Verbinski',
#  'James Gunn',
#  'Jared Bush',
#  'Chris Miller',
#  'Robert Stromberg',
#  'Neil Burger',
#  'Joel Coen',
#  'Chad Stahelski',
#  'Alejandro G. IÃ\x8cÃ\x8eÃ¥Â±Ã\x8cÃ\x8eÃ\x8cÂ\x81rritu',
#  'Sam Mendes',
#  'Bryan Singer',
#  'Martin Scorsese',
#  'Josh Boone',
#  'Paul Weitz',
#  'Brian Fee',
#  'Dennis Dugan',
#  'Tom McGrath',
#  'Tim Story',
#  'Christopher Miller',
#  'Nicholas Stoller',
#  'Brad Peyton']

# %%
directors_df = pd.DataFrame(director_list,columns=["Director"])

# %%
directors_df
# Out:
#                Director
# 0         Phil Johnston
# 1           David Slade
# 2    Genndy Tartakovsky
# 3          Peter Ramsey
# 4          Nathan Greno
# ..                  ...
# 175         Tom McGrath
# 176           Tim Story
# 177  Christopher Miller
# 178    Nicholas Stoller
# 179         Brad Peyton
#
# [180 rows x 1 columns]

# %%
directors_df["Director"]
# Out:
# 0           Phil Johnston
# 1             David Slade
# 2      Genndy Tartakovsky
# 3            Peter Ramsey
# 4            Nathan Greno
#               ...
# 175           Tom McGrath
# 176             Tim Story
# 177    Christopher Miller
# 178      Nicholas Stoller
# 179           Brad Peyton
# Name: Director, Length: 180, dtype: object

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
   
for director in tqdm(director_list):
    gross = 0
    vote_count = 0
    popularity = 0 
    vote_average = 0
    movie_count = 0
    for index, row in df10.iterrows():
        if director in row['Director']:
            gross = row['Adj. Lifetime Gross'] + gross
            vote_count = row['Vote Count'] + vote_count
            popularity = row['Popularity'] + popularity
            vote_average = row['Vote Average'] + vote_average
            movie_count += 1
    directors_df.loc[directors_df['Director'] == director, 'Adj. Lifetime Gross'] = gross
    directors_df.loc[directors_df['Director'] == director, 'Vote Count'] = vote_count
    directors_df.loc[directors_df['Director'] == director, 'Popularity'] = popularity
    directors_df.loc[directors_df['Director'] == director, 'Vote Average'] = vote_average
    directors_df.loc[directors_df['Director'] == director, 'Movie Count'] = movie_count
    movie_count = 0
    gross = 0
    vote_count = 0
    popularity = 0 
    vote_average = 0
# Out:
# HBox(children=(IntProgress(value=0, max=180), HTML(value='')))

# %%
directors_df
# Out:
#                Director  Adj. Lifetime Gross  Vote Count  Popularity  \
# 0         Phil Johnston          208736430.0      3767.0      25.144
# 1           David Slade          365229470.0      5528.0      19.466
# 2    Genndy Tartakovsky          533201710.0     11250.0      45.342
# 3          Peter Ramsey          197646100.0      1031.0      92.698
# 4          Nathan Greno          235812910.0      7235.0      20.340
# ..                  ...                  ...         ...         ...
# 175         Tom McGrath          609058430.0     12633.0      40.791
# 176           Tim Story          158756850.0      1417.0      13.084
# 177  Christopher Miller          682808770.0     18097.0      46.306
# 178    Nicholas Stoller          169032930.0      4964.0      11.360
# 179         Brad Peyton          169761920.0      5638.0      25.142
#
#      Vote Average  Movie Count
# 0             7.2          1.0
# 1             6.1          1.0
# 2            20.4          3.0
# 3             6.3          1.0
# 4             7.6          1.0
# ..            ...          ...
# 175          19.7          3.0
# 176           6.2          1.0
# 177          21.1          3.0
# 178           6.2          1.0
# 179           6.1          1.0
#
# [180 rows x 6 columns]

# %%
directors_df['Adj. Lifetime Gross Average'] = directors_df['Adj. Lifetime Gross'] / directors_df['Movie Count']
directors_df['Vote Count Average'] = directors_df['Vote Count'] / directors_df['Movie Count']
directors_df['Popularity Average'] = directors_df['Popularity'] / directors_df['Movie Count']
directors_df['Vote Average'] = directors_df['Vote Average'] / directors_df['Movie Count']

# %%
directors_df
# Out:
#                Director  Adj. Lifetime Gross  Vote Count  Popularity  \
# 0         Phil Johnston          208736430.0      3767.0      25.144
# 1           David Slade          365229470.0      5528.0      19.466
# 2    Genndy Tartakovsky          533201710.0     11250.0      45.342
# 3          Peter Ramsey          197646100.0      1031.0      92.698
# 4          Nathan Greno          235812910.0      7235.0      20.340
# ..                  ...                  ...         ...         ...
# 175         Tom McGrath          609058430.0     12633.0      40.791
# 176           Tim Story          158756850.0      1417.0      13.084
# 177  Christopher Miller          682808770.0     18097.0      46.306
# 178    Nicholas Stoller          169032930.0      4964.0      11.360
# 179         Brad Peyton          169761920.0      5638.0      25.142
#
#      Vote Average  Movie Count  Adj. Lifetime Gross Average  \
# 0        7.200000          1.0                 2.087364e+08
# 1        6.100000          1.0                 3.652295e+08
# 2        6.800000          3.0                 1.777339e+08
# 3        6.300000          1.0                 1.976461e+08
# 4        7.600000          1.0                 2.358129e+08
# ..            ...          ...                          ...
# 175      6.566667          3.0                 2.030195e+08
# 176      6.200000          1.0                 1.587568e+08
# 177      7.033333          3.0                 2.276029e+08
# 178      6.200000          1.0                 1.690329e+08
# 179      6.100000          1.0                 1.697619e+08
#
#      Vote Count Average  Popularity Average
# 0           3767.000000           25.144000
# 1           5528.000000           19.466000
# 2           3750.000000           15.114000
# 3           1031.000000           92.698000
# 4           7235.000000           20.340000
# ..                  ...                 ...
# 175         4211.000000           13.597000
# 176         1417.000000           13.084000
# 177         6032.333333           15.435333
# 178         4964.000000           11.360000
# 179         5638.000000           25.142000
#
# [180 rows x 9 columns]

# %%
directors_df.describe()
# Out:
#        Adj. Lifetime Gross    Vote Count  Popularity  Vote Average  \
# count         1.800000e+02    180.000000  180.000000    180.000000
# mean          4.289624e+08  11577.066667   39.829567      6.884574
# std           3.706358e+08  10372.409750   38.251134      0.601078
# min           1.387800e+08   1031.000000    3.070000      5.500000
# 25%           1.910864e+08   4539.000000   17.124250      6.400000
# 50%           2.840881e+08   8818.500000   26.390500      6.987500
# 75%           5.299719e+08  14536.750000   45.388250      7.300000
# max           2.301639e+09  71345.000000  297.571000      8.200000
#
#        Movie Count  Adj. Lifetime Gross Average  Vote Count Average  \
# count   180.000000                 1.800000e+02          180.000000
# mean      1.577778                 2.573544e+08         7046.907593
# std       0.884096                 1.128625e+08         3946.121827
# min       1.000000                 1.387800e+08         1031.000000
# 25%       1.000000                 1.778246e+08         3933.500000
# 50%       1.000000                 2.137334e+08         6796.250000
# 75%       2.000000                 3.078003e+08         9420.000000
# max       5.000000                 7.195185e+08        21908.000000
#
#        Popularity Average
# count          180.000000
# mean            24.509853
# std             17.228195
# min              3.070000
# 25%             15.350000
# 50%             20.290250
# 75%             28.715250
# max            148.785500

# %%
directors_df_top_grossing = directors_df.sort_values(by='Adj. Lifetime Gross Average', ascending=False)

# %%
directors_df_top_20_grossing = directors_df_top_grossing.head(20)

# %%
directors_df_top_20_grossing = directors_df_top_20_grossing.sort_values(by="Adj. Lifetime Gross Average", ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


plt.style.use('fivethirtyeight')
#plt.ticklabel_format(style='plain', axis='y')

fig, ax = plt.subplots(figsize=(15,10))


ax.bar(directors_df_top_20_grossing["Director"], directors_df_top_20_grossing["Adj. Lifetime Gross Average"])
ax.axhline(directors_df["Adj. Lifetime Gross Average"].mean(), color="red", label="Average all directors")
#ax.ticklabel_format(useOffset=False, style='plain')


ax.set_xticklabels(directors_df_top_20_grossing["Director"], rotation=80)

ax.set_ylabel("Number of players")
ax.set_title('Number of players per country')

plt.show()

# %%
conda install -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Bryan/opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.2                |           py37_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda                                           pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
# conda-4.8.2          | 3.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#convert list to string and generate
unique_string=(" ").join(word_directors)
wordcloud = WordCloud(width = 1000, height = 500, background_color="black").generate(word_directors)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()
