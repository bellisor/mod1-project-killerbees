# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#df = pd.read_csv('movies_raw_data.csv', encoding='latin-1')

# %%
df
# Out:
#       Rank                               Title Adj. Lifetime Gross  \
# 0        1                  Gone with the Wind      $1,895,421,694
# 1        2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2        3                  The Sound of Music      $1,335,086,324
# 3        4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4        5                             Titanic      $1,270,101,626
# ..     ...                                 ...                 ...
# 995    996   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 996    997                        Mystic River        $138,398,648
# 997    998                         Sea of Love        $138,240,295
# 998    999                            Scrooged        $138,234,673
# 999  1,000                Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# 0     $200,852,579      202,286,200  1939             0
# ...

# %%
actor = pd.Series(df['Actor'])

# %%
df['Actor'] = df['Actor'].map(lambda x: x.rstrip("]"))

# %%
df
# Out:
#       Rank                               Title Adj. Lifetime Gross  \
# 0        1                  Gone with the Wind      $1,895,421,694
# 1        2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2        3                  The Sound of Music      $1,335,086,324
# 3        4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4        5                             Titanic      $1,270,101,626
# ..     ...                                 ...                 ...
# 995    996   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 996    997                        Mystic River        $138,398,648
# 997    998                         Sea of Love        $138,240,295
# 998    999                            Scrooged        $138,234,673
# 999  1,000                Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# 0     $200,852,579      202,286,200  1939             0
# ...

# %%
actors = list(df['Actor'])
actors[2]
# Out:
# "['Julie Andrews', 'Christopher Plummer', 'Eleanor Parker', 'Richard Haydn'"

# %%
i = 0
test = []
while i < 1000:
    test.append(actors[i].split(", "))
    i+=1

# %%
test
# Out:
# [["['Clark Gable'",
#   "'Vivien Leigh'",
#   "'Thomas Mitchell'",
#   '"Barbara O\'Neil"'],
#  ["['Mark Hamill'", "'Harrison Ford'", "'Carrie Fisher'", "'Alec Guinness'"],
#  ["['Julie Andrews'",
#   "'Christopher Plummer'",
#   "'Eleanor Parker'",
#   "'Richard Haydn'"],
#  ["['Henry Thomas'", "'Drew Barrymore'", "'Peter Coyote'", "'Dee Wallace'"],
#  ["['Leonardo DiCaprio'", "'Kate Winslet'", "'Billy Zane'", "'Kathy Bates'"],
#  ["['Charlton Heston'",
#   "'Yul Brynner'",
#   "'Anne Baxter'",
#   "'Edward G. Robinson'"],
#  ["['Roy Scheider'", "'Robert Shaw'", "'Richard Dreyfuss'", "'Lorraine Gary'"],
#  ["['Omar Sharif'",
#   "'Julie Christie'",
#   "'Geraldine Chaplin'",
#   "'Rod Steiger'"],
#  ["['Ellen Burstyn'", "'Max von Sydow'", "'Linda Blair'", "'Lee J. Cobb'"],
#  ["['Adriana Caselotti'",
#   "'Harry Stockwell'",
#   "'Lucille La Verne'",
#   "'Roy Atwell'"],
#  ["['Daisy Ridley'", "'John Boyega'", "'Oscar Isaac'", "'Domhnall Gleeson'"],
#  ["['Rod Taylor'",
# ...

# %%
actor_list = []
for sublist in test:
    for x in sublist:
        actor_list.extend(x.split(","))
actor_list
# Out:
# ["['Clark Gable'",
#  "'Vivien Leigh'",
#  "'Thomas Mitchell'",
#  '"Barbara O\'Neil"',
#  "['Mark Hamill'",
#  "'Harrison Ford'",
#  "'Carrie Fisher'",
#  "'Alec Guinness'",
#  "['Julie Andrews'",
#  "'Christopher Plummer'",
#  "'Eleanor Parker'",
#  "'Richard Haydn'",
#  "['Henry Thomas'",
#  "'Drew Barrymore'",
#  "'Peter Coyote'",
#  "'Dee Wallace'",
#  "['Leonardo DiCaprio'",
#  "'Kate Winslet'",
#  "'Billy Zane'",
#  "'Kathy Bates'",
#  "['Charlton Heston'",
#  "'Yul Brynner'",
#  "'Anne Baxter'",
#  "'Edward G. Robinson'",
#  "['Roy Scheider'",
#  "'Robert Shaw'",
#  "'Richard Dreyfuss'",
#  "'Lorraine Gary'",
#  "['Omar Sharif'",
#  "'Julie Christie'",
#  "'Geraldine Chaplin'",
#  "'Rod Steiger'",
#  "['Ellen Burstyn'",
#  "'Max von Sydow'",
#  "'Linda Blair'",
#  "'Lee J. Cobb'",
#  "['Adriana Caselotti'",
#  "'Harry Stockwell'",
#  "'Lucille La Verne'",
#  "'Roy Atwell'",
#  "['Daisy Ridley'",
#  "'John Boyega'",
#  "'Oscar Isaac'",
#  "'Domhnall Gleeson'",
# ...

# %%
actors = set(actor_list)

# %%
actors = list(actors)
actors
# Out:
# ["'Franka Potente'",
#  "'DeForest Kelley'",
#  "'Margaret Avery'",
#  "'Christo Jivkov'",
#  "['Will Ferrell'",
#  "'John Neville'",
#  "'Eric Sykes'",
#  "['Louis C.K.'",
#  "'Martin Freeman'",
#  "['Jessica Chastain'",
#  "'Oliver Reed'",
#  "'Dawn Didawick'",
#  "'Richard Roundtree'",
#  "'Will Smith'",
#  "'Brian Keith'",
#  "'Rene Russo'",
#  "'Miranda Cosgrove'",
#  "'Lili Taylor'",
#  "'Olivia Williams'",
#  "'Claudine Auger'",
#  "'Greg Grunberg'",
#  "['Meryl Streep'",
#  "'Hugh Grant'",
#  "['Alden Ehrenreich'",
#  "['Dan Monahan'",
#  "'Elisabeth Shue'",
#  "'Justin Bartha'",
#  "'Kevin Costner'",
#  "'Demi Moore'",
#  "['Jacqueline Bisset'",
#  "'Clancy Brown'",
#  "'Joel Edgerton'",
#  '"Ed O\'Neill"',
#  "'Aidan Quinn'",
#  "'Harvey Korman'",
#  "'Shelley Winters'",
#  "'Philip Seymour Hoffman'",
#  "['Dan Castellaneta'",
#  "'Temuera Morrison'",
#  "'Christian Stevens'",
#  "'Edwin Neal'",
#  "'Hayden Panettiere'",
#  "'Paul Sand'",
#  "'Steve Valentine'",
# ...

# %%
actors_df = pd.DataFrame(actors, columns = ['Actor'])

# %%
actors_df
# Out:
#                       Actor
# 0          'Franka Potente'
# 1         'DeForest Kelley'
# 2          'Margaret Avery'
# 3          'Christo Jivkov'
# 4           ['Will Ferrell'
# ...                     ...
# 2206   'Alexandra Daddario'
# 2207           'Dafne Keen'
# 2208  'Matthew McConaughey'
# 2209    ['Steve Guttenberg'
# 2210     ['Kelly Macdonald'
#
# [2211 rows x 1 columns]

# %%
conda install tqdm
# Out:
# ...
# Solving environment: done
# ^C
#
# CondaError: KeyboardInterrupt
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
#import tqdm
# adj_gross = 0
# for x, y in actors_df.iterrows():
#     for index, row in df.iterrows():
#         if str(y) in row['Actor']:
#             actors_df['Adj. Lifetime Gross'] = actors_df['Adj. Lifetime Gross'] + row['Adj. Lifetime Gross']
#             print (adj_gross)
#             adj_gross +=1
            

gross = 0            
for actor in tqdm(actors):
    for index, row in df.iterrows():
        #if actor in row.values:
        movie_count = 0
        if actor in row['Actor']:
        #if row[row['Actor'].isin(actor)].values for actor in df['Actor']:
            gross = float(row['Adj. Lifetime Gross'].replace("$",'').replace(",",'')) + gross
            movie_count += 1
            #print(gross)
        actors_df.loc[actors_df['Actor'] == actor, 'Adj. Lifetime Gross'] = gross
        actors_df.loc[actors_df['Actor'] == actor, 'Movie Count'] = movie_count
#        df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
#        set_value(index, 'Adj. Lifetime Gross', gross)
        movie_count = 0
        gross = 0

#             gross = actors_df['Adj. Lifetime Gross'] + row['Adj. Lifetime Gross']                    
#             actors_df.set_value(index, 'Adj. Lifetime Gross', gross)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5fb4944f8eb9> in <module>
#      20             #print(gross)
#      21         actors_df.loc[actors_df['Actor'] == actor, 'Adj. Lifetime Gross'] = gross
# ---> 22         actors_df.loc[actors_df['Actor'] == actor, 'Movie Count'] = movie_count
#      23 #        df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
#      24 #        set_value(index, 'Adj. Lifetime Gross', gross)
#
# KeyboardInterrupt:

# %%
actors_df.tail()
# Out:
#                Actor  Adj. Lifetime Gross  Movie Count
# 1949  Timothy Hutton                  0.0          0.0
# 1950    Winona Ryder                  0.0          0.0
# 1951      Jon Voight                  0.0          0.0
# 1952   David Brisbin                  0.0          0.0
# 1953       Gal Gadot                  0.0          0.0

# %%
actors_df.to_csv (r'test.csv', index = False, header=True)

# %%
test  = '$1,895,421,694'
float(test.replace("$",'').replace(",",''))
# Out:
# 1895421694.0

# %%
df.to_csv (r'merged_raw_data.csv', index = False, header=True)

# %%
import pandas as pd

df = pd.read_csv('merged_raw_data.csv', encoding='latin-1')

# %%
df
# Out:
#       Rank                               Title Adj. Lifetime Gross  \
# 0        1                  Gone with the Wind      $1,895,421,694
# 1        2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2        3                  The Sound of Music      $1,335,086,324
# 3        4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4        5                             Titanic      $1,270,101,626
# ..     ...                                 ...                 ...
# 995    996   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 996    997                        Mystic River        $138,398,648
# 997    998                         Sea of Love        $138,240,295
# 998    999                            Scrooged        $138,234,673
# 999  1,000                Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# 0     $200,852,579      202,286,200  1939             0
# ...

# %%
df20 = df.loc[(df['Year'] >= 2000)]

# %%
df20
# Out:
#       Rank                                       Title Adj. Lifetime Gross  \
# 10      11  Star Wars: Episode VII - The Force Awakens      $1,013,038,487
# 14      15                                      Avatar        $911,790,952
# 15      16                           Avengers: Endgame        $892,669,593
# 28      29                                The Avengers        $720,376,844
# 29      30                              Jurassic World        $719,518,552
# ..     ...                                         ...                 ...
# 990    991                     Lee Daniels' The Butler        $138,780,007
# 991    992                             Horrible Bosses        $138,715,354
# 995    996           Spy Kids 2: Island of Lost Dreams        $138,438,939
# 996    997                                Mystic River        $138,398,648
# 999  1,000                        Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# ...

# %%
df10 = df.loc[(df['Year'] >= 2010)]

# %%
df10
# Out:
#       Rank                                       Title Adj. Lifetime Gross  \
# 10      11  Star Wars: Episode VII - The Force Awakens      $1,013,038,487
# 15      16                           Avengers: Endgame        $892,669,593
# 28      29                                The Avengers        $720,376,844
# 29      30                              Jurassic World        $719,518,552
# 30      31                               Black Panther        $714,671,451
# ..     ...                                         ...                 ...
# 980    981                           The Peanuts Movie        $140,233,294
# 985    986                        The Legend of Tarzan        $139,441,529
# 990    991                     Lee Daniels' The Butler        $138,780,007
# 991    992                             Horrible Bosses        $138,715,354
# 999  1,000                        Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# ...

# %%
actors = list(df['Actor'])

# %%
actors
# Out:
# ['Clark Gable, Vivien Leigh, Thomas Mitchell, Barbara ONeil',
#  'Mark Hamill, Harrison Ford, Carrie Fisher, Alec Guinness',
#  'Julie Andrews, Christopher Plummer, Eleanor Parker, Richard Haydn',
#  'Henry Thomas, Drew Barrymore, Peter Coyote, Dee Wallace',
#  'Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates',
#  'Charlton Heston, Yul Brynner, Anne Baxter, Edward G. Robinson',
#  'Roy Scheider, Robert Shaw, Richard Dreyfuss, Lorraine Gary',
#  'Omar Sharif, Julie Christie, Geraldine Chaplin, Rod Steiger',
#  'Ellen Burstyn, Max von Sydow, Linda Blair, Lee J. Cobb',
#  'Adriana Caselotti, Harry Stockwell, Lucille La Verne, Roy Atwell',
#  'Daisy Ridley, John Boyega, Oscar Isaac, Domhnall Gleeson',
#  'Rod Taylor, Betty Lou Gerson, J. Pat OMalley, Martha Wentworth',
#  'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#  'Charlton Heston, Jack Hawkins, Stephen Boyd, Haya Harareet',
#  'Sam Worthington, Zoe Saldana, Sigourney Weaver, Michelle Rodriguez',
# ...

# %%
df['Actor'] = df['Actor'].map(lambda x: x.replace("  "," "))

# %%
df
# Out:
#       Rank                               Title Adj. Lifetime Gross  \
# 0        1                  Gone with the Wind      $1,895,421,694
# 1        2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2        3                  The Sound of Music      $1,335,086,324
# 3        4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4        5                             Titanic      $1,270,101,626
# ..     ...                                 ...                 ...
# 995    996   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 996    997                        Mystic River        $138,398,648
# 997    998                         Sea of Love        $138,240,295
# 998    999                            Scrooged        $138,234,673
# 999  1,000                Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# 0     $200,852,579      202,286,200  1939             0
# ...

# %%
df.to_csv (r'merged_raw_data_clean.csv', index = False, header=True)

# %%
df10 = df.loc[(df['Year'] >= 2010)]
df10
# Out:
#       Rank                                       Title Adj. Lifetime Gross  \
# 10      11  Star Wars: Episode VII - The Force Awakens      $1,013,038,487
# 15      16                           Avengers: Endgame        $892,669,593
# 28      29                                The Avengers        $720,376,844
# 29      30                              Jurassic World        $719,518,552
# 30      31                               Black Panther        $714,671,451
# ..     ...                                         ...                 ...
# 980    981                           The Peanuts Movie        $140,233,294
# 985    986                        The Legend of Tarzan        $139,441,529
# 990    991                     Lee Daniels' The Butler        $138,780,007
# 991    992                             Horrible Bosses        $138,715,354
# 999  1,000                        Central Intelligence        $138,115,674
#
#     Lifetime Gross Est. Num Tickets  Year        Budget  \
# ...

# %%
actors_list = list(df['Actor'])
actors_list
actors_list2 = ','.join(actors_list)

# %%
actors_list2
# Out:
# 'Clark Gable, Vivien Leigh, Thomas Mitchell, Barbara ONeil,Mark Hamill, Harrison Ford, Carrie Fisher, Alec Guinness,Julie Andrews, Christopher Plummer, Eleanor Parker, Richard Haydn,Henry Thomas, Drew Barrymore, Peter Coyote, Dee Wallace,Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates,Charlton Heston, Yul Brynner, Anne Baxter, Edward G. Robinson,Roy Scheider, Robert Shaw, Richard Dreyfuss, Lorraine Gary,Omar Sharif, Julie Christie, Geraldine Chaplin, Rod Steiger,Ellen Burstyn, Max von Sydow, Linda Blair, Lee J. Cobb,Adriana Caselotti, Harry Stockwell, Lucille La Verne, Roy Atwell,Daisy Ridley, John Boyega, Oscar Isaac, Domhnall Gleeson,Rod Taylor, Betty Lou Gerson, J. Pat OMalley, Martha Wentworth,Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams,Charlton Heston, Jack Hawkins, Stephen Boyd, Haya Harareet,Sam Worthington, Zoe Saldana, Sigourney Weaver, Michelle Rodriguez,Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth,Mark Hamill, Harrison Ford, Carr
# ...

# %%
df["Budget"] = pd.to_numeric(df["Budget"], downcast="float")
df
# Out:
#       Rank                               Title  Adj. Lifetime Gross  \
# 0        1                  Gone with the Wind         1.895422e+09
# 1        2  Star Wars: Episode IV - A New Hope         1.668980e+09
# 2        3                  The Sound of Music         1.335086e+09
# 3        4          E.T. the Extra-Terrestrial         1.329175e+09
# 4        5                             Titanic         1.270102e+09
# ..     ...                                 ...                  ...
# 995    996   Spy Kids 2: Island of Lost Dreams         1.384389e+08
# 996    997                        Mystic River         1.383987e+08
# 997    998                         Sea of Love         1.382403e+08
# 998    999                            Scrooged         1.382347e+08
# 999  1,000                Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 0       200852576.0       202286208.0  1939          0.0
# ...

# %%
df.to_csv (r'merged_raw_data_clean.csv', index = False, header=True)

# %%
df = df[df["Budget"] != 0]

# %%
df
# Out:
#       Rank                               Title  Adj. Lifetime Gross  \
# 1        2  Star Wars: Episode IV - A New Hope         1.668980e+09
# 2        3                  The Sound of Music         1.335086e+09
# 3        4          E.T. the Extra-Terrestrial         1.329175e+09
# 4        5                             Titanic         1.270102e+09
# 6        7                                Jaws         1.200098e+09
# ..     ...                                 ...                  ...
# 995    996   Spy Kids 2: Island of Lost Dreams         1.384389e+08
# 996    997                        Mystic River         1.383987e+08
# 997    998                         Sea of Love         1.382403e+08
# 998    999                            Scrooged         1.382347e+08
# 999  1,000                Central Intelligence         1.381157e+08
#
#      Lifetime Gross  Est. Num Tickets  Year       Budget  \
# 1       460998496.0       178119504.0  1977   11000000.0
# ...

# %%
df.to_csv (r'merged_raw_data_clean.csv', index = False, header=True)

# %%
df10 = df.loc[(df['Year'] >= 2010)]
df10
# Out:
#       Rank                                       Title  Adj. Lifetime Gross  \
# 10      11  Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 15      16                           Avengers: Endgame         8.926696e+08
# 28      29                                The Avengers         7.203768e+08
# 29      30                              Jurassic World         7.195185e+08
# 30      31                               Black Panther         7.146714e+08
# ..     ...                                         ...                  ...
# 980    981                           The Peanuts Movie         1.402333e+08
# 985    986                        The Legend of Tarzan         1.394415e+08
# 990    991                     Lee Daniels' The Butler         1.387800e+08
# 991    992                             Horrible Bosses         1.387154e+08
# 999  1,000                        Central Intelligence         1.381157e+08
#
# ...

# %%
df10.to_csv (r'merged_raw_data_clean_decade.csv', index = False, header=True)

# %%
df10
# Out:
#       Rank                                       Title  Adj. Lifetime Gross  \
# 10      11  Star Wars: Episode VII - The Force Awakens         1.013038e+09
# 15      16                           Avengers: Endgame         8.926696e+08
# 28      29                                The Avengers         7.203768e+08
# 29      30                              Jurassic World         7.195185e+08
# 30      31                               Black Panther         7.146714e+08
# ..     ...                                         ...                  ...
# 980    981                           The Peanuts Movie         1.402333e+08
# 985    986                        The Legend of Tarzan         1.394415e+08
# 990    991                     Lee Daniels' The Butler         1.387800e+08
# 991    992                             Horrible Bosses         1.387154e+08
# 999  1,000                        Central Intelligence         1.381157e+08
#
# ...

# %%
actors_list = list(df10['Actor'])
actors_list
actors_list2 = ','.join(actors_list)

# %%
actors_list2
# Out:
# 'Daisy Ridley, John Boyega, Oscar Isaac, Domhnall Gleeson,Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth,Robert Downey Jr., Chris Evans, Scarlett Johansson, Jeremy Renner,Chris Pratt, Bryce Dallas Howard, Ty Simpkins, Judy Greer,Chadwick Boseman, Michael B. Jordan, Lupita Nyongo, Danai Gurira,Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans,Daisy Ridley, John Boyega, Mark Hamill, Carrie Fisher,Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner,Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen,Donald Glover, BeyoncÌÎå©, Seth Rogen, Chiwetel Ejiofor,Christian Bale, Tom Hardy, Anne Hathaway, Gary Oldman,Emma Watson, Dan Stevens, Luke Evans, Josh Gad,Ellen DeGeneres, Albert Brooks, Ed ONeill, Kaitlin Olson,Carrie Fisher, Mark Hamill, Adam Driver, Daisy Ridley,Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth,Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty,Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Philip Seymour Hoffman,Kristen Bell, 
# ...

# %%
actors_list3 = actors_list2.replace(",",", ")

# %%
actors_list4 = actors_list3.replace("  ","")

# %%
actors_list5 = actors_list4.replace(",",", ")

# %%
actors_list6 = actors_list5.replace("  "," ")

# %%
actors_list6
# Out:
# 'Daisy Ridley, John Boyega, Oscar Isaac, Domhnall Gleeson, Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth, Robert Downey Jr., Chris Evans, Scarlett Johansson, Jeremy Renner, Chris Pratt, Bryce Dallas Howard, Ty Simpkins, Judy Greer, Chadwick Boseman, Michael B. Jordan, Lupita Nyongo, Danai Gurira, Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans, Daisy Ridley, John Boyega, Mark Hamill, Carrie Fisher, Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner, Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen, Donald Glover, BeyoncÌÎå©, Seth Rogen, Chiwetel Ejiofor, Christian Bale, Tom Hardy, Anne Hathaway, Gary Oldman, Emma Watson, Dan Stevens, Luke Evans, Josh Gad, Ellen DeGeneres, Albert Brooks, Ed ONeill, Kaitlin Olson, Carrie Fisher, Mark Hamill, Adam Driver, Daisy Ridley, Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth, Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty, Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Philip Seymour Hoffma
# ...

# %%
word_actors = actors_list6.replace(" ","")

# %%
actor_list = actors_list6.split(", ")

# %%
actor_list = list(set(actor_list))

# %%
len(actor_list)
# Out:
# 567

# %%
actor_list
# Out:
# ['Danielle Nicolet',
#  'Katy Perry',
#  'David Schwimmer',
#  'Jonathan Groff',
#  'Logan Marshall-Green',
#  'Mark Wahlberg',
#  'James Franco',
#  'Kevin James',
#  'Mindy Kaling',
#  'Kristen Bell',
#  'Kevin Bacon',
#  'Chiwetel Ejiofor',
#  'Steve Zahn',
#  'Gwyneth Paltrow',
#  'Joaquin Phoenix',
#  'Jason Bateman',
#  'Chris Evans',
#  'Lisa Kudrow',
#  'Corey Hawkins',
#  'Rebel Wilson',
#  'Kyle Gallner',
#  'Judy Greer',
#  'Rashida Jones',
#  'Jason Statham',
#  'Emily Blunt',
#  'Diego Luna',
#  'Zach Galifianakis',
#  'Larry the Cable Guy',
#  'Philip Seymour Hoffman',
#  'Jada Pinkett Smith',
#  'Michael Douglas',
#  'Jaeden Martell',
#  'Javier Bardem',
#  'Bill SkarsgÌÎå«rd',
#  'Ed Harris',
#  'Kaitlin Olson',
#  'Aaron Taylor-Johnson',
#  'Derek Jeter',
#  'Boyd Holbrook',
#  'Ben Hardy',
#  'Eddie Redmayne',
#  'Jennifer Aniston',
#  'Martin Lawrence',
#  'Linda Cardellini',
#  'Alan Tudyk',
#  'Gemma Chan',
#  'Zendaya',
#  'Don Cheadle',
#  'Leland Orser',
# ...

# %%
test_actor_list = ['Danielle Nicolet',
 'Katy Perry',
 'David Schwimmer',
 'Jonathan Groff']

# %%
actors_df = pd.DataFrame(actor_list,columns=["Actor"])

# %%
actors_df
# Out:
#                     Actor
# 0        Danielle Nicolet
# 1              Katy Perry
# 2         David Schwimmer
# 3          Jonathan Groff
# 4    Logan Marshall-Green
# ..                    ...
# 562     Robert Downey Jr.
# 563           Ben Stiller
# 564     Justin Timberlake
# 565      James Badge Dale
# 566              Tina Fey
#
# [567 rows x 1 columns]

# %%
actors_df["Actor"]
# Out:
# 0          Danielle Nicolet
# 1                Katy Perry
# 2           David Schwimmer
# 3            Jonathan Groff
# 4      Logan Marshall-Green
#                ...
# 562       Robert Downey Jr.
# 563             Ben Stiller
# 564       Justin Timberlake
# 565        James Badge Dale
# 566                Tina Fey
# Name: Actor, Length: 567, dtype: object

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
   
for actor in tqdm(actor_list):
    gross = 0
    vote_count = 0
    popularity = 0 
    vote_average = 0
    movie_count = 0
    for index, row in df10.iterrows():
        if actor in row['Actor']:
            gross = row['Adj. Lifetime Gross'] + gross
            vote_count = row['Vote Count'] + vote_count
            popularity = row['Popularity'] + popularity
            vote_average = row['Vote Average'] + vote_average
            movie_count += 1
    actors_df.loc[actors_df['Actor'] == actor, 'Adj. Lifetime Gross'] = gross
    actors_df.loc[actors_df['Actor'] == actor, 'Vote Count'] = vote_count
    actors_df.loc[actors_df['Actor'] == actor, 'Popularity'] = popularity
    actors_df.loc[actors_df['Actor'] == actor, 'Vote Average'] = vote_average
    actors_df.loc[actors_df['Actor'] == actor, 'Movie Count'] = movie_count
    movie_count = 0
    gross = 0
    vote_count = 0
    popularity = 0 
    vote_average = 0

# %%
actors_df
# Out:
#                     Actor  Adj. Lifetime Gross  Movie Count  Vote Count  \
# 0        Danielle Nicolet         1.381157e+08          1.0      3561.0
# 1              Katy Perry         1.683676e+08          1.0      2414.0
# 2         David Schwimmer         2.521158e+08          1.0      3813.0
# 3          Jonathan Groff         9.365353e+08          2.0     13813.0
# 4    Logan Marshall-Green         1.466096e+08          1.0      8046.0
# ..                    ...                  ...          ...         ...
# 562     Robert Downey Jr.         4.632188e+09          9.0    130331.0
# 563           Ben Stiller         4.273563e+08          2.0      5935.0
# 564     Justin Timberlake         1.638251e+08          1.0      2097.0
# 565      James Badge Dale         2.346051e+08          1.0     10076.0
# 566              Tina Fey         1.737236e+08          1.0      4126.0
#
#      Popularity  Vote Average
# 0        13.460           6.3
# 1        11.447           5.7
# ...

# %%
actors_df['Adj. Lifetime Gross Average'] = actors_df['Adj. Lifetime Gross'] / actors_df['Movie Count']
actors_df['Vote Count Average'] = actors_df['Vote Count'] / actors_df['Movie Count']
actors_df['Popularity Average'] = actors_df['Popularity'] / actors_df['Movie Count']
actors_df['Vote Average'] = actors_df['Vote Average'] / actors_df['Movie Count']

# %%
actors_df
# Out:
#                     Actor  Adj. Lifetime Gross  Movie Count  Vote Count  \
# 0        Danielle Nicolet         1.381157e+08          1.0      3561.0
# 1              Katy Perry         1.683676e+08          1.0      2414.0
# 2         David Schwimmer         2.521158e+08          1.0      3813.0
# 3          Jonathan Groff         9.365353e+08          2.0     13813.0
# 4    Logan Marshall-Green         1.466096e+08          1.0      8046.0
# ..                    ...                  ...          ...         ...
# 562     Robert Downey Jr.         4.632188e+09          9.0    130331.0
# 563           Ben Stiller         4.273563e+08          2.0      5935.0
# 564     Justin Timberlake         1.638251e+08          1.0      2097.0
# 565      James Badge Dale         2.346051e+08          1.0     10076.0
# 566              Tina Fey         1.737236e+08          1.0      4126.0
#
#      Popularity  Vote Average  Adj. Lifetime Gross Average  \
# ...

# %%
actors_df.describe()
# Out:
#        Adj. Lifetime Gross  Movie Count     Vote Count  Popularity  \
# count         5.670000e+02   567.000000     567.000000  567.000000
# mean          4.462102e+08     1.679012   12474.469136   23.582844
# std           4.481194e+08     1.257894   13563.951710   14.353815
# min           1.381157e+08     1.000000     981.000000    0.950000
# 25%           1.831020e+08     1.000000    4440.500000   15.254833
# 50%           2.846194e+08     1.000000    8926.000000   20.719500
# 75%           5.409193e+08     2.000000   14549.000000   28.098833
# max           4.632188e+09    10.000000  130331.000000  148.785500
#
#        Vote Average  Adj. Lifetime Gross Average  Vote Count Average  \
# count    567.000000                 5.670000e+02          567.000000
# mean       5.437821                 2.570130e+08         7032.647799
# std        2.123362                 1.194686e+08         3778.672293
# min        0.682000                 1.381157e+08          981.000000
# ...

# %%
actors_df_top_grossing = actors_df.sort_values(by='Adj. Lifetime Gross', ascending=False)

# %%
actors_df_top_20_grossing = actors_df_top_grossing.head(20)

# %%
actors_df_top_20_grossing = actors_df_top_20_grossing.sort_values(by="Adj. Lifetime Gross", ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


plt.style.use('fivethirtyeight')
#plt.ticklabel_format(style='plain', axis='y')

fig, ax = plt.subplots(figsize=(15,10))


ax.bar(actors_df_top_20_grossing["Actor"], actors_df_top_20_grossing["Adj. Lifetime Gross"])
ax.axhline(actors_df["Adj. Lifetime Gross"].mean(), color="red", label="Average all actors")
#ax.ticklabel_format(useOffset=False, style='plain')


ax.set_xticklabels(actors_df_top_20_grossing["Actor"], rotation=80)

ax.set_ylabel("Number of players")
ax.set_title('Number of players per country')

plt.show()

# %%
conda install -c conda-forge wordcloud
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Bryan/opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.2                |           py37_0         3.0 MB  conda-forge
#     wordcloud-1.6.0            |   py37h0b31af3_0         167 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.1.3-py37h9aa3819_0
#   wordcloud          conda-forge/osx-64::wordcloud-1.6.0-py37h0b31af3_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda                                           pkgs/main --> conda-forge
#
#
#
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#convert list to string and generate
unique_string=(" ").join(actor_list2)
wordcloud = WordCloud(width = 1000, height = 500, background_color="black").generate(word_actors)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()
