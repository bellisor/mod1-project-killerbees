# %%
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import our merged data for analysis

df = pd.read_csv('merged_raw_data_clean_decade.csv')

# %% [markdown]
# Investigate our Data

# %%
df.head()
# Out:
#   Rank                                       Title  Adj. Lifetime Gross  \
# 0   11  Star Wars: Episode VII - The Force Awakens           1013038460
# 1   16                           Avengers: Endgame            892669600
# 2   29                                The Avengers            720376800
# 3   30                              Jurassic World            719518500
# 4   31                               Black Panther            714671400
#
#    Lifetime Gross  Est. Num Tickets  Year     Budget  \
# 0       936662200         108115100  2015  245000000
# 1       858373000          95268900  2019  356000000
# 2       623357900          76881200  2012  220000000
# 3       652270660          76789600  2015  150000000
# 4       700059600          76272300  2018  202003950
#
#                    Director  \
# 0               J.J. Abrams
# 1  Anthony Russo, Joe Russo
# 2               Joss Whedon
# 3           Colin Trevorrow
# 4              Ryan Coogler
#
# ...

# %%
df.set_index('Title')
# Out:
#                                              Rank  Adj. Lifetime Gross  \
# Title
# Star Wars: Episode VII - The Force Awakens     11           1013038460
# Avengers: Endgame                              16            892669600
# The Avengers                                   29            720376800
# Jurassic World                                 30            719518500
# Black Panther                                  31            714671400
# ...                                           ...                  ...
# The Peanuts Movie                             981            140233300
# The Legend of Tarzan                          986            139441540
# Lee Daniels' The Butler                       991            138780000
# Horrible Bosses                               992            138715360
# Central Intelligence                        1,000            138115680
#
#                                             Lifetime Gross  Est. Num Tickets  \
# Title
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Adj. Lifetime Gross', 'Lifetime Gross',
#        'Est. Num Tickets', 'Year', 'Budget', 'Director', 'Actor', 'Genre',
#        'IMDB ID', 'Vote Count', 'Vote Average', 'Popularity', 'IMDB Rating',
#        'Meta Score'],
#       dtype='object')

# %% [markdown]
# plt.figure(figsize=(8.5, 11))
# sns.set()
#
# sns.scatterplot(df[], df['popularity'], hue= df['gender'])

# %%
plt.figure(figsize=(10,10))
sns.set()

sns.scatterplot(df['IMDB Rating'], df['Adj. Lifetime Gross'], hue = df['Meta Score'])

# %%
#The takeaway away from this graph is that Microsoft should focus on Quality and viewer enjoyment,

# %%
plt.figure(figsize=(10,10))
sns.set()

sns.scatterplot(df['Meta Score'], df['Adj. Lifetime Gross'], size= df['Adj. Lifetime Gross'], hue= df['Meta Score'])

# %%
plt.figure(figsize=(10,10))
sns.set()

sns.lineplot(df['Year'], df['Budget'])
sns.lineplot(df['Year'], df['Adj. Lifetime Gross'],)

# %%
plt.figure(figsize=(10,10))
sns.set()

sns.scatterplot(df['Budget'], df['Popularity'], hue = df['Meta Score'])

# %%
plt.figure(figsize=(10,10))
sns.set()

sns.scatterplot(df['Budget'], df['Adj. Lifetime Gross'], hue = df['IMDB Rating'],)

# %%
plt.figure(figsize=(10,10))
plt.style.use('fivethirtyeight')
sns.set()

sns.scatterplot(df['Meta Score'], df['IMDB Rating'])

# %%
# graphic showing the histogram of data
fig, ax = plt.subplots(figsize=(8.,11))
# Plot a histogram of "Weight" for mens_rowing
ax.hist(df['IMDB Rating'], bins=15)

ax.set_xlabel('IMDB Rating')
ax.set_ylabel('# of Movies')
ax.set_title("Distribution of Movie Ratings")

plt.show()

# %%
# graphic showing the histogram of data
fig, ax = plt.subplots(figsize=(8.,11))
# Plot a histogram of "Weight" for mens_rowing
ax.hist(df['Adj. Lifetime Gross'], bins=15)

ax.set_xlabel('IMDB Rating')
ax.set_ylabel('# of Movies')
ax.set_title("Distribution of Movie Ratings")
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Ratings')

# %%
gdf = pd.read_csv('genres_raw_data.csv')

# %%
gdf.columns
# Out:
# Index(['Genre', 'Adj. Lifetime Gross', 'Vote Count', 'Popularity',
#        'Vote Average', 'Movie Count', 'Adj. Lifetime Gross Average',
#        'Vote Count Average', 'Popularity Average'],
#       dtype='object')

# %%
gdf.set_index(['Genre'], inplace=True)

# %%
#df.groupby(['_STATE', 'smoking'])['smoking'].count()
genre_count = gdf.groupby(['Genre', 'Movie Count'])['Movie Count'].count()

# %%
genre_count
# Out:
# Genre      Movie Count
# Action     126.0          1
# Adventure  153.0          1
# Animation  55.0           1
# Biography  11.0           1
# Comedy     90.0           1
# Crime      18.0           1
# Drama      58.0           1
# Family     71.0           1
# Fantasy    77.0           1
# History    7.0            1
# Horror     13.0           1
# Music      23.0           1
# Musical    17.0           1
# Mystery    16.0           1
# Romance    22.0           1
# Sci-Fi     81.0           1
# Sport      3.0            1
# Thriller   51.0           1
# War        7.0            1
# Western    4.0            1
# Name: Movie Count, dtype: int64

# %%
genre_count.describe()
# Out:
# count    20.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Movie Count, dtype: float64

# %%
gdf.head()
# Out:
#        Genre  Adj. Lifetime Gross  Vote Count  Popularity  Vote Average  \
# 0        War         1.725845e+09     44414.0     184.275      7.385714
# 1    History         1.315204e+09     42182.0     131.552      7.500000
# 2      Drama         1.342217e+10    401090.0    1413.263      7.179310
# 3      Music         5.966931e+09    126673.0     621.909      7.082609
# 4  Animation         1.468684e+10    287523.0    1266.493      6.881818
#
#    Movie Count  Adj. Lifetime Gross Average  Vote Count Average  \
# 0          7.0                 2.465493e+08         6344.857143
# 1          7.0                 1.878863e+08         6026.000000
# 2         58.0                 2.314166e+08         6915.344828
# 3         23.0                 2.594318e+08         5507.521739
# 4         55.0                 2.670334e+08         5227.690909
#
#    Popularity Average
# 0           26.325000
# 1           18.793143
# 2           24.366603
# 3           27.039522
# 4           23.027145

# %%
gdf.head(20)
# Out:
#         Genre  Adj. Lifetime Gross  Vote Count  Popularity  Vote Average  \
# 0         War         1.725845e+09     44414.0     184.275      7.385714
# 1     History         1.315204e+09     42182.0     131.552      7.500000
# 2       Drama         1.342217e+10    401090.0    1413.263      7.179310
# 3       Music         5.966931e+09    126673.0     621.909      7.082609
# 4   Animation         1.468684e+10    287523.0    1266.493      6.881818
# 5      Sci-Fi         2.677755e+10    823661.0    2218.797      6.950617
# 6      Family         1.913071e+10    397259.0    1661.245      6.832394
# 7     Fantasy         2.136786e+10    525798.0    2140.579      6.792208
# 8     Romance         5.198265e+09    133728.0     461.303      6.740909
# 9      Action         3.648115e+10   1064403.0    3317.993      6.860317
# 10    Western         7.415577e+08     36941.0      79.629      7.375000
# 11     Comedy         2.149602e+10    507426.0    2121.160      6.740000
# ...

# %%
gmdf= pd.read_csv('genres_raw_data_main.csv')

# %%
gmdf
# Out:
#        Genre  Adj. Lifetime Gross  IMDB Rating  Meta Score
# 0        War          432102240.0          7.4        76.0
# 1        War          403659600.0          7.3        72.0
# 2        War          212998850.0          7.3        86.0
# 3        War          198969140.0          7.9        94.0
# 4        War          174968820.0          7.6        63.0
# ..       ...                  ...          ...         ...
# 898  Musical          167025870.0          6.9        63.0
# 899  Musical          163825090.0          6.5        56.0
# 900  Musical          160300080.0          8.0        93.0
# 901  Musical          148094720.0          6.3        49.0
# 902  Musical          147317010.0          5.9        69.0
#
# [903 rows x 4 columns]

# %%
gmdf.describe()
# Out:
#        Adj. Lifetime Gross  IMDB Rating  Meta Score
# count         9.030000e+02   903.000000  903.000000
# mean          2.691514e+08     7.041750   63.576966
# std           1.363029e+08     0.795062   14.135408
# min           1.381157e+08     4.100000   19.000000
# 25%           1.737236e+08     6.600000   55.000000
# 50%           2.207028e+08     7.100000   64.000000
# 75%           3.365039e+08     7.600000   74.000000
# max           1.013038e+09     8.800000   96.000000

# %%
gmdf.columns
# Out:
# Index(['Genre', 'Adj. Lifetime Gross', 'IMDB Rating', 'Meta Score'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.boxplot(x=gmdf['Genre'], y=gmdf['IMDB Rating'])

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.boxplot(x=gmdf['Genre'], y=gmdf['Adj. Lifetime Gross'])
ax

# %%
gmdf.tail(18)
# Out:
#        Genre  Adj. Lifetime Gross  IMDB Rating  Meta Score
# 885   Horror          146570220.0          7.3        62.0
# 886  Musical          565223700.0          6.9        55.0
# 887  Musical          532199140.0          7.1        65.0
# 888  Musical          477021100.0          7.1        64.0
# 889  Musical          459514180.0          7.5        74.0
# 890  Musical          369758940.0          7.0        53.0
# 891  Musical          287344160.0          7.1        59.0
# 892  Musical          264867410.0          7.6        81.0
# 893  Musical          252317230.0          6.4        46.0
# 894  Musical          235812910.0          7.7        71.0
# 895  Musical          178666220.0          6.7        66.0
# 896  Musical          178195860.0          7.6        48.0
# 897  Musical          174968820.0          7.6        63.0
# 898  Musical          167025870.0          6.9        63.0
# 899  Musical          163825090.0          6.5        56.0
# ...
